# %%
# Import the dependencies.
import pandas as pd
import requests
import json
import citipy
from citipy import citipy
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
import random
from config import weather_api_key
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ________________
# Create a set of 2,000 random latitudes and longitudes
# ----------------------
# ----------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# ________________
# Get nearest city using citipy module
# ----------------------
# ----------------------

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
         
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Using a tuple() function to display the latitude and longitude combinations.
##for coordinate in coordinates:
##    print(citipy.nearest_city(coordinate[0], coordinate[0]).city_name,
##          citipy.nearest_city(coordinate[0], coordinate[0]).country_code)

# %% [markdown]
# ---------------
# Perform an API call with the OpenWeatherMap.
# ---------------
# ---------------

# %% [markdown]
# ---------------------------------------
#
# Retrieve the following information from the API call:
#
#     Latitude and longitude
#     Maximum temperature
#     Percent humidity
#     Percent cloudiness
#     Wind speed
#     Weather description (for example, clouds, fog, light rain, clear sky)
#
# ---------------------------------------

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        ### city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
#                          "Date": city_date}

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | eyl
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | souillac
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | australind
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | port hedland
# Processing Record 14 of Set 1 | zalantun
# Processing Record 15 of Set 1 | barao de melgaco
# Processing Record 16 of Set 1 | esperance
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | teneguiban
# City not found. Skipping...
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | basco
# Processing Record 21 of Set 1 | linqiong
# Processing Record 22 of Set 1 | vagamo
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | shahr-e kord
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | kabin buri
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | pevek
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | monrovia
# Processing Record 35 of Set 1 | boguchany
# Processing Record 36 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | komsomolskiy
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | vardo
# Processing Record 47 of Set 1 | codrington
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 1 | talnakh
# Processing Record 50 of Set 1 | quelimane
# Processing Record 1 of Set 2 | salalah
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | tautira
# Processing Record 6 of Set 2 | north bend
# Processing Record 7 of Set 2 | poya
# Processing Record 8 of Set 2 | thinadhoo
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | aswan
# Processing Record 13 of Set 2 | hamilton
# Processing Record 14 of Set 2 | haines junction
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | rio grande
# Processing Record 17 of Set 2 | port-gentil
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | belmonte
# Processing Record 20 of Set 2 | maxixe
# Processing Record 21 of Set 2 | maketu
# Processing Record 22 of Set 2 | vila franca do campo
# Processing Record 23 of Set 2 | le port
# Processing Record 24 of Set 2 | faanui
# Processing Record 25 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 2 | guanay
# Processing Record 27 of Set 2 | bundibugyo
# Processing Record 28 of Set 2 | kapit
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | kushima
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | lagoa
# Processing Record 33 of Set 2 | puri
# Processing Record 34 of Set 2 | kyabe
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | luganville
# Processing Record 37 of Set 2 | ostrovnoy
# Processing Record 38 of Set 2 | tual
# Processing Record 39 of Set 2 | grafton
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | yar-sale
# Processing Record 42 of Set 2 | antalaha
# Processing Record 43 of Set 2 | leningradskiy
# Processing Record 44 of Set 2 | vung tau
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | college
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | port lincoln
# Processing Record 49 of Set 2 | ayan
# Processing Record 50 of Set 2 | cidreira
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | miri
# Processing Record 3 of Set 3 | nome
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | marystown
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | pacific grove
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | issenye
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | ascension
# Processing Record 12 of Set 3 | xacmaz
# Processing Record 13 of Set 3 | chake chake
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | fortuna
# Processing Record 16 of Set 3 | puerto del rosario
# Processing Record 17 of Set 3 | adrar
# Processing Record 18 of Set 3 | te anau
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | xam nua
# Processing Record 21 of Set 3 | zirandaro
# Processing Record 22 of Set 3 | suamico
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | isangel
# Processing Record 25 of Set 3 | pocone
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | storm lake
# Processing Record 28 of Set 3 | punta arenas
# Processing Record 29 of Set 3 | cherskiy
# Processing Record 30 of Set 3 | mixtequilla
# City not found. Skipping...
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | guanajay
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | hilo
# Processing Record 36 of Set 3 | walvis bay
# Processing Record 37 of Set 3 | mount isa
# Processing Record 38 of Set 3 | pandan
# Processing Record 39 of Set 3 | senanga
# Processing Record 40 of Set 3 | shahr-e babak
# Processing Record 41 of Set 3 | nurota
# Processing Record 42 of Set 3 | lugovoy
# Processing Record 43 of Set 3 | namatanai
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | naze
# Processing Record 46 of Set 3 | turayf
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | sao joao da barra
# Processing Record 49 of Set 3 | beringovskiy
# Processing Record 50 of Set 3 | tiksi
# Processing Record 1 of Set 4 | katsuura
# Processing Record 2 of Set 4 | castro
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | saint-pierre
# Processing Record 5 of Set 4 | fort-shevchenko
# Processing Record 6 of Set 4 | arraial do cabo
# Processing Record 7 of Set 4 | narsaq
# Processing Record 8 of Set 4 | burica
# City not found. Skipping...
# Processing Record 9 of Set 4 | huangzhai
# Processing Record 10 of Set 4 | mahebourg
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | pidhaytsi
# Processing Record 13 of Set 4 | mayumba
# Processing Record 14 of Set 4 | bubaque
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | mareeba
# Processing Record 17 of Set 4 | vangaindrano
# Processing Record 18 of Set 4 | mairana
# Processing Record 19 of Set 4 | shimoda
# Processing Record 20 of Set 4 | norman wells
# Processing Record 21 of Set 4 | oyotun
# Processing Record 22 of Set 4 | reconquista
# Processing Record 23 of Set 4 | tocopilla
# Processing Record 24 of Set 4 | hukuntsi
# Processing Record 25 of Set 4 | butaritari
# Processing Record 26 of Set 4 | las juntas
# Processing Record 27 of Set 4 | wadsworth
# Processing Record 28 of Set 4 | rocha
# Processing Record 29 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 4 | santa isabel do rio negro
# Processing Record 31 of Set 4 | provideniya
# Processing Record 32 of Set 4 | carnarvon
# Processing Record 33 of Set 4 | portree
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | hambantota
# Processing Record 36 of Set 4 | liuzhou
# Processing Record 37 of Set 4 | ermoupolis
# Processing Record 38 of Set 4 | saint-georges
# Processing Record 39 of Set 4 | fayaoue
# Processing Record 40 of Set 4 | dondo
# Processing Record 41 of Set 4 | batagay-alyta
# Processing Record 42 of Set 4 | imbituba
# Processing Record 43 of Set 4 | bandarbeyla
# Processing Record 44 of Set 4 | praia
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | bambous virieux
# Processing Record 47 of Set 4 | port blair
# Processing Record 48 of Set 4 | saint george
# Processing Record 49 of Set 4 | kismayo
# Processing Record 50 of Set 4 | hoi an
# Processing Record 1 of Set 5 | kupang
# Processing Record 2 of Set 5 | grindavik
# Processing Record 3 of Set 5 | canico
# Processing Record 4 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 5 | saint stephen
# Processing Record 6 of Set 5 | obluche
# City not found. Skipping...
# Processing Record 7 of Set 5 | tateyama
# Processing Record 8 of Set 5 | inhambane
# Processing Record 9 of Set 5 | shirokiy
# Processing Record 10 of Set 5 | lata
# Processing Record 11 of Set 5 | brigantine
# Processing Record 12 of Set 5 | zharkent
# Processing Record 13 of Set 5 | hokitika
# Processing Record 14 of Set 5 | mokhsogollokh
# Processing Record 15 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 16 of Set 5 | aklavik
# Processing Record 17 of Set 5 | dingle
# Processing Record 18 of Set 5 | hirara
# Processing Record 19 of Set 5 | maneadero
# Processing Record 20 of Set 5 | chapleau
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | brod
# Processing Record 23 of Set 5 | ixtapa
# Processing Record 24 of Set 5 | morbach
# Processing Record 25 of Set 5 | panzhihua
# Processing Record 26 of Set 5 | chuncheng
# Processing Record 27 of Set 5 | kamenka
# Processing Record 28 of Set 5 | lufilufi
# Processing Record 29 of Set 5 | tigzirt
# Processing Record 30 of Set 5 | chlorakas
# Processing Record 31 of Set 5 | pisco
# Processing Record 32 of Set 5 | chinsali
# Processing Record 33 of Set 5 | sumy
# Processing Record 34 of Set 5 | chapais
# Processing Record 35 of Set 5 | bardiyah
# Processing Record 36 of Set 5 | bom jesus
# Processing Record 37 of Set 5 | ponta do sol
# Processing Record 38 of Set 5 | yumen
# Processing Record 39 of Set 5 | berlevag
# Processing Record 40 of Set 5 | caconda
# Processing Record 41 of Set 5 | klaksvik
# Processing Record 42 of Set 5 | key largo
# Processing Record 43 of Set 5 | port hardy
# Processing Record 44 of Set 5 | kiunga
# Processing Record 45 of Set 5 | imeni poliny osipenko
# Processing Record 46 of Set 5 | aki
# Processing Record 47 of Set 5 | maimbung
# Processing Record 48 of Set 5 | luderitz
# Processing Record 49 of Set 5 | taltal
# Processing Record 50 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 1 of Set 6 | aykhal
# Processing Record 2 of Set 6 | south sioux city
# Processing Record 3 of Set 6 | sidney
# Processing Record 4 of Set 6 | waingapu
# Processing Record 5 of Set 6 | port-cartier
# Processing Record 6 of Set 6 | imuris
# Processing Record 7 of Set 6 | airai
# Processing Record 8 of Set 6 | lircay
# Processing Record 9 of Set 6 | carira
# Processing Record 10 of Set 6 | ribeira grande
# Processing Record 11 of Set 6 | westport
# Processing Record 12 of Set 6 | bristol
# Processing Record 13 of Set 6 | mercedes
# Processing Record 14 of Set 6 | rio gallegos
# Processing Record 15 of Set 6 | najran
# Processing Record 16 of Set 6 | ganzhou
# Processing Record 17 of Set 6 | acarau
# Processing Record 18 of Set 6 | gloversville
# Processing Record 19 of Set 6 | severodvinsk
# Processing Record 20 of Set 6 | mar del plata
# Processing Record 21 of Set 6 | batyrevo
# Processing Record 22 of Set 6 | meulaboh
# Processing Record 23 of Set 6 | dakoro
# Processing Record 24 of Set 6 | bintulu
# Processing Record 25 of Set 6 | varhaug
# Processing Record 26 of Set 6 | zhigansk
# Processing Record 27 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 6 | heinola
# Processing Record 29 of Set 6 | naryan-mar
# Processing Record 30 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 31 of Set 6 | sorland
# Processing Record 32 of Set 6 | halle
# Processing Record 33 of Set 6 | nishihara
# Processing Record 34 of Set 6 | sakakah
# Processing Record 35 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 6 | marihatag
# Processing Record 37 of Set 6 | bembereke
# Processing Record 38 of Set 6 | hanzhong
# Processing Record 39 of Set 6 | broken hill
# Processing Record 40 of Set 6 | cockburn town
# Processing Record 41 of Set 6 | bathsheba
# Processing Record 42 of Set 6 | sao filipe
# Processing Record 43 of Set 6 | azad shahr
# Processing Record 44 of Set 6 | aquiraz
# Processing Record 45 of Set 6 | katangli
# Processing Record 46 of Set 6 | caravelas
# Processing Record 47 of Set 6 | coracora
# Processing Record 48 of Set 6 | trapani
# Processing Record 49 of Set 6 | namibe
# Processing Record 50 of Set 6 | vestmannaeyjar
# Processing Record 1 of Set 7 | soyo
# Processing Record 2 of Set 7 | labuhan
# Processing Record 3 of Set 7 | ndioum
# Processing Record 4 of Set 7 | saint-joseph
# Processing Record 5 of Set 7 | geraldton
# Processing Record 6 of Set 7 | yashkul
# Processing Record 7 of Set 7 | alofi
# Processing Record 8 of Set 7 | taoudenni
# Processing Record 9 of Set 7 | burns lake
# Processing Record 10 of Set 7 | dudinka
# Processing Record 11 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 7 | aritao
# Processing Record 13 of Set 7 | kalabo
# Processing Record 14 of Set 7 | salinas
# Processing Record 15 of Set 7 | iqaluit
# Processing Record 16 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 7 | tucurui
# Processing Record 18 of Set 7 | hasaki
# Processing Record 19 of Set 7 | rocky mountain house
# Processing Record 20 of Set 7 | bukama
# Processing Record 21 of Set 7 | singaraja
# Processing Record 22 of Set 7 | krasnoshchekovo
# Processing Record 23 of Set 7 | nouakchott
# Processing Record 24 of Set 7 | chyhyryn
# Processing Record 25 of Set 7 | frankfort
# Processing Record 26 of Set 7 | half moon bay
# Processing Record 27 of Set 7 | banat
# Processing Record 28 of Set 7 | sciacca
# Processing Record 29 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 7 | tignere
# Processing Record 31 of Set 7 | christchurch
# Processing Record 32 of Set 7 | kruisfontein
# Processing Record 33 of Set 7 | middlebury
# Processing Record 34 of Set 7 | hohhot
# Processing Record 35 of Set 7 | bontang
# Processing Record 36 of Set 7 | nanortalik
# Processing Record 37 of Set 7 | gigmoto
# Processing Record 38 of Set 7 | gravdal
# Processing Record 39 of Set 7 | ruteng
# Processing Record 40 of Set 7 | lavrentiya
# Processing Record 41 of Set 7 | bage
# Processing Record 42 of Set 7 | lazarev
# Processing Record 43 of Set 7 | dunedin
# Processing Record 44 of Set 7 | blanquefort
# Processing Record 45 of Set 7 | tahmek
# Processing Record 46 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 7 | mahibadhoo
# Processing Record 48 of Set 7 | puerto madryn
# Processing Record 49 of Set 7 | moron
# Processing Record 50 of Set 7 | ingham
# Processing Record 1 of Set 8 | margate
# Processing Record 2 of Set 8 | idah
# Processing Record 3 of Set 8 | viedma
# Processing Record 4 of Set 8 | sarangani
# Processing Record 5 of Set 8 | takoradi
# Processing Record 6 of Set 8 | oksfjord
# Processing Record 7 of Set 8 | jardim
# Processing Record 8 of Set 8 | doha
# Processing Record 9 of Set 8 | hamina
# Processing Record 10 of Set 8 | elat
# Processing Record 11 of Set 8 | riachao
# Processing Record 12 of Set 8 | semporna
# Processing Record 13 of Set 8 | selfoss
# Processing Record 14 of Set 8 | nantucket
# Processing Record 15 of Set 8 | canton
# Processing Record 16 of Set 8 | kaltasy
# Processing Record 17 of Set 8 | balabac
# Processing Record 18 of Set 8 | yulara
# Processing Record 19 of Set 8 | nieuw amsterdam
# Processing Record 20 of Set 8 | tomatlan
# Processing Record 21 of Set 8 | prieska
# Processing Record 22 of Set 8 | sidhauli
# Processing Record 23 of Set 8 | seabra
# Processing Record 24 of Set 8 | suzhou
# Processing Record 25 of Set 8 | buraydah
# Processing Record 26 of Set 8 | hervey bay
# Processing Record 27 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 8 | inirida
# Processing Record 29 of Set 8 | mayo
# Processing Record 30 of Set 8 | lala
# Processing Record 31 of Set 8 | champerico
# Processing Record 32 of Set 8 | ekibastuz
# Processing Record 33 of Set 8 | burkburnett
# Processing Record 34 of Set 8 | ocos
# Processing Record 35 of Set 8 | roswell
# Processing Record 36 of Set 8 | thompson
# Processing Record 37 of Set 8 | daru
# Processing Record 38 of Set 8 | sabang
# Processing Record 39 of Set 8 | hualmay
# Processing Record 40 of Set 8 | husavik
# Processing Record 41 of Set 8 | poum
# Processing Record 42 of Set 8 | tazovskiy
# Processing Record 43 of Set 8 | mogochin
# City not found. Skipping...
# Processing Record 44 of Set 8 | blagesti
# Processing Record 45 of Set 8 | lorengau
# Processing Record 46 of Set 8 | alindao
# Processing Record 47 of Set 8 | zonguldak
# Processing Record 48 of Set 8 | dighwara
# Processing Record 49 of Set 8 | cuamba
# Processing Record 50 of Set 8 | san pietro in casale
# Processing Record 1 of Set 9 | touros
# Processing Record 2 of Set 9 | glowno
# Processing Record 3 of Set 9 | eydhafushi
# Processing Record 4 of Set 9 | mount gambier
# Processing Record 5 of Set 9 | skibbereen
# Processing Record 6 of Set 9 | nador
# Processing Record 7 of Set 9 | mahon
# Processing Record 8 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 9 | malpe
# Processing Record 10 of Set 9 | pinawa
# Processing Record 11 of Set 9 | nouadhibou
# Processing Record 12 of Set 9 | mbanza-ngungu
# Processing Record 13 of Set 9 | guerrero negro
# Processing Record 14 of Set 9 | tiznit
# Processing Record 15 of Set 9 | salekhard
# Processing Record 16 of Set 9 | vila velha
# Processing Record 17 of Set 9 | palmer
# Processing Record 18 of Set 9 | sibu
# Processing Record 19 of Set 9 | miraflores
# Processing Record 20 of Set 9 | aklera
# Processing Record 21 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 23 of Set 9 | pitea
# Processing Record 24 of Set 9 | keelung
# Processing Record 25 of Set 9 | slavyanka
# Processing Record 26 of Set 9 | tefe
# Processing Record 27 of Set 9 | monze
# Processing Record 28 of Set 9 | verkhnetulomskiy
# Processing Record 29 of Set 9 | singkawang
# Processing Record 30 of Set 9 | straumen
# Processing Record 31 of Set 9 | moranbah
# Processing Record 32 of Set 9 | nalut
# Processing Record 33 of Set 9 | brownwood
# Processing Record 34 of Set 9 | mlonggo
# Processing Record 35 of Set 9 | kissidougou
# Processing Record 36 of Set 9 | canitas
# City not found. Skipping...
# Processing Record 37 of Set 9 | markova
# Processing Record 38 of Set 9 | kommunar
# Processing Record 39 of Set 9 | opuwo
# Processing Record 40 of Set 9 | aldan
# Processing Record 41 of Set 9 | san cristobal
# Processing Record 42 of Set 9 | batagay
# Processing Record 43 of Set 9 | sitka
# Processing Record 44 of Set 9 | cape coast
# Processing Record 45 of Set 9 | padang
# Processing Record 46 of Set 9 | mkushi
# Processing Record 47 of Set 9 | sioux lookout
# Processing Record 48 of Set 9 | ngunguru
# Processing Record 49 of Set 9 | rabo de peixe
# Processing Record 50 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 10 | tura
# Processing Record 3 of Set 10 | vostok
# Processing Record 4 of Set 10 | tucuma
# Processing Record 5 of Set 10 | ust-nera
# Processing Record 6 of Set 10 | gushikawa
# Processing Record 7 of Set 10 | karratha
# Processing Record 8 of Set 10 | la ronge
# Processing Record 9 of Set 10 | bella union
# Processing Record 10 of Set 10 | kungurtug
# Processing Record 11 of Set 10 | santa helena
# Processing Record 12 of Set 10 | kolokani
# Processing Record 13 of Set 10 | synya
# Processing Record 14 of Set 10 | egvekinot
# Processing Record 15 of Set 10 | alice
# Processing Record 16 of Set 10 | novaya igirma
# Processing Record 17 of Set 10 | kahama
# Processing Record 18 of Set 10 | okhotsk
# Processing Record 19 of Set 10 | parkersburg
# Processing Record 20 of Set 10 | hebertville
# City not found. Skipping...
# Processing Record 21 of Set 10 | himeji
# Processing Record 22 of Set 10 | amuntai
# Processing Record 23 of Set 10 | muscat
# Processing Record 24 of Set 10 | hofn
# Processing Record 25 of Set 10 | miamisburg
# Processing Record 26 of Set 10 | ilulissat
# Processing Record 27 of Set 10 | pangnirtung
# Processing Record 28 of Set 10 | itoman
# Processing Record 29 of Set 10 | vao
# Processing Record 30 of Set 10 | changji
# Processing Record 31 of Set 10 | buchanan
# Processing Record 32 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 10 | belaya gora
# Processing Record 34 of Set 10 | jinhua
# Processing Record 35 of Set 10 | bahraich
# Processing Record 36 of Set 10 | kuryk
# Processing Record 37 of Set 10 | cayenne
# Processing Record 38 of Set 10 | the valley
# Processing Record 39 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 40 of Set 10 | amapa
# Processing Record 41 of Set 10 | san carlos de bariloche
# Processing Record 42 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 10 | baruun-urt
# Processing Record 44 of Set 10 | delta
# Processing Record 45 of Set 10 | san joaquin
# Processing Record 46 of Set 10 | kaeo
# Processing Record 47 of Set 10 | la asuncion
# Processing Record 48 of Set 10 | chardara
# Processing Record 49 of Set 10 | maniitsoq
# Processing Record 50 of Set 10 | kaitangata
# Processing Record 1 of Set 11 | phan thiet
# Processing Record 2 of Set 11 | clarence town
# Processing Record 3 of Set 11 | taphan hin
# Processing Record 4 of Set 11 | guadalupe y calvo
# Processing Record 5 of Set 11 | tilichiki
# Processing Record 6 of Set 11 | mantua
# Processing Record 7 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 11 | omsukchan
# Processing Record 9 of Set 11 | naron
# Processing Record 10 of Set 11 | muriti
# Processing Record 11 of Set 11 | dosso
# Processing Record 12 of Set 11 | panama city
# Processing Record 13 of Set 11 | wagrowiec
# Processing Record 14 of Set 11 | divnomorskoye
# Processing Record 15 of Set 11 | cabay
# Processing Record 16 of Set 11 | namwala
# Processing Record 17 of Set 11 | sola
# Processing Record 18 of Set 11 | severo-kurilsk
# Processing Record 19 of Set 11 | addi ugri
# City not found. Skipping...
# Processing Record 20 of Set 11 | mayaposi
# City not found. Skipping...
# Processing Record 21 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 11 | talaya
# Processing Record 23 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 11 | adre
# Processing Record 25 of Set 11 | sisimiut
# Processing Record 26 of Set 11 | haapiti
# Processing Record 27 of Set 11 | uige
# Processing Record 28 of Set 11 | kimbe
# Processing Record 29 of Set 11 | arlit
# Processing Record 30 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 32 of Set 11 | southbridge
# Processing Record 33 of Set 11 | juegang
# Processing Record 34 of Set 11 | port augusta
# Processing Record 35 of Set 11 | tizimin
# Processing Record 36 of Set 11 | chute-aux-outardes
# Processing Record 37 of Set 11 | escarcega
# Processing Record 38 of Set 11 | port loko
# Processing Record 39 of Set 11 | lahad datu
# Processing Record 40 of Set 11 | sao lourenco do sul
# Processing Record 41 of Set 11 | sur
# Processing Record 42 of Set 11 | pringsewu
# Processing Record 43 of Set 11 | san juan
# Processing Record 44 of Set 11 | mitu
# Processing Record 45 of Set 11 | auki
# Processing Record 46 of Set 11 | mitsamiouli
# Processing Record 47 of Set 11 | roald
# Processing Record 48 of Set 11 | druzhba
# Processing Record 49 of Set 11 | strezhevoy
# Processing Record 50 of Set 11 | kintampo
# Processing Record 1 of Set 12 | kavaratti
# Processing Record 2 of Set 12 | malartic
# Processing Record 3 of Set 12 | baykit
# Processing Record 4 of Set 12 | preobrazheniye
# Processing Record 5 of Set 12 | chara
# Processing Record 6 of Set 12 | aginskoye
# Processing Record 7 of Set 12 | beaverlodge
# Processing Record 8 of Set 12 | ribeirao branco
# Processing Record 9 of Set 12 | otradnoye
# Processing Record 10 of Set 12 | ranfurly
# Processing Record 11 of Set 12 | penzance
# Processing Record 12 of Set 12 | bartica
# Processing Record 13 of Set 12 | muzhi
# Processing Record 14 of Set 12 | kashary
# Processing Record 15 of Set 12 | cochrane
# Processing Record 16 of Set 12 | muisne
# Processing Record 17 of Set 12 | amberley
# Processing Record 18 of Set 12 | dodoma
# Processing Record 19 of Set 12 | flinders
# Processing Record 20 of Set 12 | anjiang
# Processing Record 21 of Set 12 | taksimo
# Processing Record 22 of Set 12 | road town
# Processing Record 23 of Set 12 | turkistan
# Processing Record 24 of Set 12 | peto
# Processing Record 25 of Set 12 | mangai
# Processing Record 26 of Set 12 | pauini
# Processing Record 27 of Set 12 | rovaniemi
# Processing Record 28 of Set 12 | panarukan
# Processing Record 29 of Set 12 | srednekolymsk
# Processing Record 30 of Set 12 | richards bay
# Processing Record 31 of Set 12 | taylorville
# Processing Record 32 of Set 12 | gat
# Processing Record 33 of Set 12 | fairbanks
# Processing Record 34 of Set 12 | chicama
# Processing Record 35 of Set 12 | tessalit
# Processing Record 36 of Set 12 | devyatka
# City not found. Skipping...
# Processing Record 37 of Set 12 | paragould
# Processing Record 38 of Set 12 | noumea
# Processing Record 39 of Set 12 | longyearbyen
# Processing Record 40 of Set 12 | kushmurun
# Processing Record 41 of Set 12 | puerto escondido
# Processing Record 42 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 12 | san miguelito
# Processing Record 44 of Set 12 | seoul
# Processing Record 45 of Set 12 | hay river
# Processing Record 46 of Set 12 | bangkalan
# Processing Record 47 of Set 12 | ferrol
# Processing Record 48 of Set 12 | port alberni
# Processing Record 49 of Set 12 | teya
# Processing Record 50 of Set 12 | fort nelson
# Processing Record 1 of Set 13 | dabat
# Processing Record 2 of Set 13 | jawhar
# Processing Record 3 of Set 13 | bud
# Processing Record 4 of Set 13 | goderich
# Processing Record 5 of Set 13 | manacapuru
# Processing Record 6 of Set 13 | sungai besar
# Processing Record 7 of Set 13 | honningsvag
# Processing Record 8 of Set 13 | maceio
# Processing Record 9 of Set 13 | balkanabat
# Processing Record 10 of Set 13 | pochutla
# Processing Record 11 of Set 13 | burley
# Processing Record 12 of Set 13 | mammaste
# Processing Record 13 of Set 13 | ullapool
# Processing Record 14 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 15 of Set 13 | puerto baquerizo moreno
# Processing Record 16 of Set 13 | mehamn
# Processing Record 17 of Set 13 | coquimbo
# Processing Record 18 of Set 13 | limulunga
# Processing Record 19 of Set 13 | zalari
# Processing Record 20 of Set 13 | udachnyy
# Processing Record 21 of Set 13 | kudahuvadhoo
# Processing Record 22 of Set 13 | liusha
# Processing Record 23 of Set 13 | namtsy
# Processing Record 24 of Set 13 | samarai
# Processing Record 25 of Set 13 | kalisz
# Processing Record 26 of Set 13 | mecca
# Processing Record 27 of Set 13 | lensk
# Processing Record 28 of Set 13 | peno
# Processing Record 29 of Set 13 | sai buri
# Processing Record 30 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 31 of Set 13 | suriapet
# Processing Record 32 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 33 of Set 13 | innisfail
# Processing Record 34 of Set 13 | la grande
# Processing Record 35 of Set 13 | bonoua
# Processing Record 36 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 13 | charters towers
# Processing Record 38 of Set 13 | san juan ixcoy
# Processing Record 39 of Set 13 | shingu
# Processing Record 40 of Set 13 | malabugas
# Processing Record 41 of Set 13 | ust-karsk
# Processing Record 42 of Set 13 | lucapa
# Processing Record 43 of Set 13 | nanakuli
# Processing Record 44 of Set 13 | upata
# Processing Record 45 of Set 13 | peleduy
# Processing Record 46 of Set 13 | am timan
# Processing Record 47 of Set 13 | andenes
# Processing Record 48 of Set 13 | santa marta
# Processing Record 49 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 50 of Set 13 | sept-iles
# Processing Record 1 of Set 14 | leh
# Processing Record 2 of Set 14 | san rafael
# Processing Record 3 of Set 14 | isla mujeres
# Processing Record 4 of Set 14 | megion
# Processing Record 5 of Set 14 | ambilobe
# Processing Record 6 of Set 14 | tarauaca
# Processing Record 7 of Set 14 | xai-xai
# Processing Record 8 of Set 14 | ahipara
# Processing Record 9 of Set 14 | sambava
# Processing Record 10 of Set 14 | sumenep
# Processing Record 11 of Set 14 | manta
# Processing Record 12 of Set 14 | chernyshevskiy
# Processing Record 13 of Set 14 | ewa beach
# Processing Record 14 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 15 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 14 | ahuimanu
# Processing Record 17 of Set 14 | kemijarvi
# Processing Record 18 of Set 14 | paamiut
# Processing Record 19 of Set 14 | chikodi
# Processing Record 20 of Set 14 | burriana
# Processing Record 21 of Set 14 | sagarejo
# Processing Record 22 of Set 14 | kirakira
# Processing Record 23 of Set 14 | redmond
# Processing Record 24 of Set 14 | victoria
# Processing Record 25 of Set 14 | sulangan
# Processing Record 26 of Set 14 | kenai
# Processing Record 27 of Set 14 | kununurra
# Processing Record 28 of Set 14 | shache
# Processing Record 29 of Set 14 | tigil
# Processing Record 30 of Set 14 | comodoro rivadavia
# Processing Record 31 of Set 14 | abatskoye
# Processing Record 32 of Set 14 | corner brook
# Processing Record 33 of Set 14 | svetlaya
# Processing Record 34 of Set 14 | akyab
# Processing Record 35 of Set 14 | santa maria
# Processing Record 36 of Set 14 | rybachiy
# Processing Record 37 of Set 14 | alta floresta
# Processing Record 38 of Set 14 | bolondron
# Processing Record 39 of Set 14 | palamos
# Processing Record 40 of Set 14 | carballo
# Processing Record 41 of Set 14 | rawson
# Processing Record 42 of Set 14 | bandundu
# Processing Record 43 of Set 14 | san juan de los morros
# Processing Record 44 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 14 | asau
# Processing Record 46 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 14 | quepos
# Processing Record 48 of Set 14 | constitucion
# Processing Record 49 of Set 14 | kuytun
# Processing Record 50 of Set 14 | lubyany
# Processing Record 1 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 3 of Set 15 | pemangkat
# Processing Record 4 of Set 15 | watertown
# Processing Record 5 of Set 15 | coihaique
# Processing Record 6 of Set 15 | santa cruz
# Processing Record 7 of Set 15 | praya
# Processing Record 8 of Set 15 | virginia beach
# Processing Record 9 of Set 15 | hami
# Processing Record 10 of Set 15 | la romana
# Processing Record 11 of Set 15 | mana
# Processing Record 12 of Set 15 | harper
# Processing Record 13 of Set 15 | boende
# Processing Record 14 of Set 15 | arak
# Processing Record 15 of Set 15 | moussoro
# Processing Record 16 of Set 15 | kasongo-lunda
# Processing Record 17 of Set 15 | cap malheureux
# Processing Record 18 of Set 15 | uglovka
# Processing Record 19 of Set 15 | smithers
# Processing Record 20 of Set 15 | santa comba
# Processing Record 21 of Set 15 | luanda
# Processing Record 22 of Set 15 | koudougou
# Processing Record 23 of Set 15 | ketchikan
# Processing Record 24 of Set 15 | la palma
# Processing Record 25 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 15 | lampazos de naranjo
# Processing Record 27 of Set 15 | lusaka
# Processing Record 28 of Set 15 | ongandjera
# Processing Record 29 of Set 15 | boralday
# Processing Record 30 of Set 15 | ha tinh
# Processing Record 31 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 15 | zlobin
# Processing Record 33 of Set 15 | oussouye
# Processing Record 34 of Set 15 | brikama
# Processing Record 35 of Set 15 | alyangula
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 672

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Eyl   7.9803   49.8164     76.77        83          14
# 1    Nikolskoye  59.7035   30.7861     67.89        94         100
# 2     Busselton -33.6500  115.3333     55.09        78         100
# 3      Souillac -20.5167   57.5167     69.37       100          75
# 4       Rikitea -23.1203 -134.9692     74.19        75           2
# 5   Tuktoyaktuk  69.4541 -133.0374     48.20        71          90
# 6        Barrow  71.2906 -156.7887     39.22        92          90
# 7    Australind -33.2667  115.7167     55.06        82         100
# 8       Ushuaia -54.8000  -68.3000     42.46        61          40
# 9  Puerto Ayora  -0.7393  -90.3518     75.16        85          64
#
#    Wind Speed Country       Description
# 0       26.40      SO        few clouds
# 1        4.47      RU   overcast clouds
# 2       24.29      AU   overcast clouds
# 3        3.44      MU     moderate rain
# 4       11.81      PF         clear sky
# 5       11.50      CA   overcast clouds
# 6        8.05      US   overcast clouds
# 7       21.74      AU   overcast clouds
# 8        6.91      AR  scattered clouds
# 9        8.99      EC     broken clouds

# %% [markdown]
# ----------------------------
# Export the dataframe into a CSV file
# ----------------------------
# ----------------------------

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
