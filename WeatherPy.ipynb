# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# In the next cell, we'll add the code that generates the latitudes and longitudes, but first, they need to be stored so that we can access them later. Since we are creating arrays of latitudes and longitudes, we'll declare each array as a variable.
#
# In the next cell, add the following code that we used to generate the random latitudes. Also, we'll create a similar code snippet that will generate longitudes. To ensure enough latitudes and longitudes, we'll start with 1,500. In addition, we'll pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# When we run this cell, the output is a zip object in memory.

# %% [markdown]
# The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple. If there are 1,500 latitudes and longitudes, there will be 1,500 tuples of paired latitudes and longitudes, where each latitude and longitude in a tuple can be accessed by the index of 0 and 1, respectively.

# %% [markdown]
# In a new Jupyter Notebook file called API_practice.ipynb, add the following lists and pack them into the zipped tuple. Then, run the cell.
#
# # Create a practice set of random latitude and longitude combinations.
# x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
# y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
# coordinates = zip(x, y)
#
# In a new cell, display the coordinate pairs with the following code.
#
# # Use the tuple() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])
#
# When we run the cell above, the output is ordered pairs of our x and y coordinates.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
#     You can only unzip a zipped tuple once before it is removed from the computer's         memory. Make sure you unzip the latitudes and longitudes into the coordinates list            before moving on.
#
# Now that we have our ordered pairs of latitudes and longitudes in a list, we can iterate through the list of tuples and find the nearest city to those coordinates.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %% [markdown]
# a for loop that will do the following:
#
#     Iterate through the coordinates' zipped tuple.
#
#     Use citipy.nearest_city() and inside the parentheses of nearest_city(), add the latitude and longitude in this format: coordinate[0], coordinate[1].
#
#     To print the city name, chain the city_name to the nearest_city() function.
#
#     To print the country name, chain the country_code to the nearest_city() function.

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# rikitea pf
# kodiak us
# ponta do sol cv
# meyungs pw
# hualmay pe
# tiksi ru
# tessaoua ne
# rikitea pf
# rio gallegos ar
# barentsburg sj
# busselton au
# mrirt ma
# olinda br
# vaini to
# mataura pf
# sentyabrskiy ru
# karkaralinsk kz
# busselton au
# hermanus za
# lolua tv
# namibe ao
# plettenberg bay za
# thompson ca
# cape town za
# provideniya ru
# sorong id
# sinnamary gf
# albany au
# pekan my
# sorvag fo
# punta arenas cl
# saskylakh ru
# nikolskoye ru
# yellowknife ca
# bredasdorp za
# rikitea pf
# pahrump us
# saskylakh ru
# road town vg
# rikitea pf
# ushuaia ar
# tiksi ru
# atuona pf
# port alfred za
# sentyabrskiy ru
# hofn is
# beringovskiy ru
# avarua ck
# bubaque gw
# calvinia za
# atuona pf
# bluff nz
# punta arenas cl
# kodiak us
# emerald au
# bluff nz
# slave lake ca
# samusu ws
# mahibadhoo mv
# kurilsk ru
# port blair in
# ushuaia ar
# rikitea pf
# nenjiang cn
# busselton au
# ballina ie
# mahebourg mu
# puerto ayora ec
# phangnga th
# meulaboh id
# punta arenas cl
# mrakovo ru
# narsaq gl
# ushuaia ar
# vaini to
# clyde river ca
# vila franca do campo pt
# port hedland au
# nouakchott mr
# adrar dz
# mudgee au
# butaritari ki
# seoul kr
# okha ru
# cape town za
# pevek ru
# hasaki jp
# kavieng pg
# dakar sn
# porto-vecchio fr
# borba br
# dingle ie
# hobart au
# clyde river ca
# port hardy ca
# hermanus za
# henties bay na
# atuona pf
# erdaojiang cn
# tovarkovskiy ru
# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
         
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
import requests
requests.__version__
# Out:
# '2.25.1'

# %%
# Import the API key.
from config import weather_api_key

# %% [markdown]
# ------------------------------------------------------
#
# Borrar   + weather_api_key
# ------------------------------------------------------
# ------------------------------------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# al final se incluyó    + weather_api_key

# %% [markdown]
# ------------------------------------------------------
# no olvidar borrar
# weather_api_key
# ------------------------------------------------------
# ------------------------------------------------------

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# a Boston le falta una 'o' por ello arroja el error 404 que significa
# que la URL no fue encontrada
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %% [markdown]
# When we run this cell the output is "<Response [200]>."
#
#
# When we receive a valid response from the server, we have to decide on the data format. The options are text, JSON, XML, or HTML format. We can apply the format attributes to get the data into a useful format to parse.
#
# One format that provides a preview of the JSON data is the text attribute. Let's get the content for the Boston weather data using the following code.

# %%
# One format that provides a preview of the JSON data is the text attribute. 
# Let's get the content for the Boston weather data using the following code.
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":80.69,"feels_like":83.79,"temp_min":76.68,"temp_max":83.41,"pressure":1015,"humidity":68},"visibility":10000,"wind":{"speed":4,"deg":309,"gust":11.99},"clouds":{"all":100},"dt":1628378227,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1628329394,"sunset":1628380606},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 80.69,
#   'feels_like': 83.79,
#   'temp_min': 76.68,
#   'temp_max': 83.41,
#   'pressure': 1015,
#   'humidity': 68},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 309, 'gust': 11.99},
#  'clouds': {'all': 100},
#  'dt': 1628378227,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1628329394,
#   'sunset': 1628380606},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4b6a64249f0a93f971d6379291fb5960&q=Boston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 80.94,
#   'feels_like': 84.2,
#   'temp_min': 76.95,
#   'temp_max': 83.41,
#   'pressure': 1015,
#   'humidity': 68},
#  'visibility': 10000,
#  'wind': {'speed': 7, 'deg': 272, 'gust': 15.01},
#  'clouds': {'all': 100},
#  'dt': 1628378060,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1628329394,
#   'sunset': 1628380606},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# _________________
# In a new cell, let's assign a variable to the city_weather.json() data to the variable "boston_data" and run the cell

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1628329394,
#  'sunset': 1628380606}

# %%
boston_data['sys']['country']
# Out:
# 'US'

# %%
# to retrieve the weather data
boston_data["dt"]
# Out:
# 1628378060

# %%
boston_data['coord']['lat']
# Out:
# 42.3584

# %%
boston_data['main']['temp_max']
# Out:
# 83.41

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 83.41 68 100 7

# %% [markdown]
# ________________
# **  Viene de API practice
# ----------------------
# ----------------------

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %% [markdown]
# ________________
# **  Viene de Random Numbers
# ----------------------
# ----------------------

# %%
# Import the random module.
import random

# %%
random.random()
#this method will launch a number between 0 and 1
# Out:
# 0.305981367079483

# %%
random.randint(-90,90)
#this method will launch an Integer Number between -90 and 90
# Out:
# -24

# %%
random.randrange(-9,9,2)
#this method will launch a number between -9 and 9 with intervals of 2
# Out:
# -7

# %%
random.uniform(-10,10)
#this method will launch a number between -10 and 10 including float (decimals)
# Out:
# -5.261452679414347

# %%
random_number = random.randint(-90,89) + random.random()
random_number
# Out:
# 27.108139205720253

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
y = 1
longitudes = []
while y < 11:
    random_long = random.randint(-180, 180) + random.random()
    longitudes.append(random_long)
    y += 1

# %%
random.randrange(-90, 90, step=1)
# Out:
# 75

# %%
# now using method  randrange(0,0, step=1)

z = 1
lon2 = []
while z < 11:
    random_lon2 = random.randrange(-180, 180, step=3) + random.random()
    lon2.append(random_lon2)
    z += 1

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# 19.42535973268376

# %%
np.random.uniform(low=-90, high=90)
# Out:
# 49.87685397961599

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ -5.82149171,  28.38835354,   3.89999663,  47.3210602 ,
#         54.12264905, -61.86223364,  22.40899019,  79.93285088,
#         62.22361559,  65.38296398, -60.12449218, -86.9582255 ,
#        -61.83786919,  54.03266303,  17.76961519,  43.41105283,
#        -19.16257763, -87.03479469,  76.81218807, -29.74257368,
#        -83.11288016,  75.21739588,  80.52664441,  20.51336123,
#        -80.7961679 , -26.42643677,  54.33146153,  41.71872935,
#         62.22128951,  25.57749859,  -9.92039657, -13.25366711,
#         28.77472857,  40.89681294,  55.36545315,  10.27186157,
#        -56.0270813 , -71.16128994,  76.11133317, -53.92170844,
#         17.02427902, -66.6512415 ,  18.7039002 , -47.65483577,
#        -58.42019969,  43.57112436, -37.92683039,  53.45685002,
#         38.72619918, -40.70113033])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 18.2 µs ± 38 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.64 ms ± 8.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ------------------------------------------
# Convert the Date Timestamp
# ------------------------------------------
# ------------------------------------------

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 8, 7, 23, 14, 20)

# %% [markdown]
# We can convert this datetime format to 2019-10-21 17:24:35 using the Python string format method strftime() and adding how we want the string to look inside the parentheses. In our case, we would use strftime('%Y-%m-%d %H:%M:%S').

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-08-07 23:14:20'

# %% [markdown]
# 1. Import our dependencies and initialize counters and an empty list that will hold the weather data.
# 2. Loop through the cities list.
# 3. Group the cities in sets of 50 to log the process as we find the weather data for each city.
#     - Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# 4. Build the city_url or endpoint for each city.
# 5. Log the URL and the record and set numbers.
# 6. Make an API request for each city.
# 7. Parse the JSON weather data for the following:
#    - City, country, and date
#    - Latitude and longitude
#    - Maximum temperature
#    - Humidity
#    - Cloudiness
#    - Wind speed
# 8. Add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Processing Record 1 of Set 13 | rikitea
# Processing Record 2 of Set 13 | kodiak
# Processing Record 3 of Set 13 | ponta do sol
# Processing Record 4 of Set 13 | meyungs
# Processing Record 5 of Set 13 | hualmay
# Processing Record 6 of Set 13 | tiksi
# Processing Record 7 of Set 13 | tessaoua
# Processing Record 8 of Set 13 | rio gallegos
# Processing Record 9 of Set 13 | barentsburg
# Processing Record 10 of Set 13 | busselton
# Processing Record 11 of Set 13 | mrirt
# Processing Record 12 of Set 13 | olinda
# Processing Record 13 of Set 13 | vaini
# Processing Record 14 of Set 13 | mataura
# Processing Record 15 of Set 13 | sentyabrskiy
# Processing Record 16 of Set 13 | karkaralinsk
# Processing Record 17 of Set 13 | hermanus
# Processing Record 18 of Set 13 | lolua
# Processing Record 19 of Set 13 | namibe
# Processing Record 20 of Set 13 | plettenberg bay
# Processing Record 21 of Set 13 | thompson
# Processing Record 22 of Set 13 | cape town
# Processing Record 23 of Set 13 | provideniya
# Processing Record 24 of Set 13 | sorong
# Processing Record 25 of Set 13 | sinnamary
# Processing Record 26 of Set 13 | albany
# Processing Record 27 of Set 13 | pekan
# Processing Record 28 of Set 13 | sorvag
# Processing Record 29 of Set 13 | punta arenas
# Processing Record 30 of Set 13 | saskylakh
# Processing Record 31 of Set 13 | nikolskoye
# Processing Record 32 of Set 13 | yellowknife
# Processing Record 33 of Set 13 | bredasdorp
# Processing Record 34 of Set 13 | pahrump
# Processing Record 35 of Set 13 | road town
# Processing Record 36 of Set 13 | ushuaia
# Processing Record 37 of Set 13 | atuona
# Processing Record 38 of Set 13 | port alfred
# Processing Record 39 of Set 13 | hofn
# Processing Record 40 of Set 13 | beringovskiy
# Processing Record 41 of Set 13 | avarua
# Processing Record 42 of Set 13 | bubaque
# Processing Record 43 of Set 13 | calvinia
# Processing Record 44 of Set 13 | bluff
# Processing Record 45 of Set 13 | emerald
# Processing Record 46 of Set 13 | slave lake
# Processing Record 47 of Set 13 | samusu
# Processing Record 48 of Set 13 | mahibadhoo
# Processing Record 49 of Set 13 | kurilsk
# Processing Record 50 of Set 13 | port blair
# Processing Record 1 of Set 14 | nenjiang
# Processing Record 2 of Set 14 | ballina
# Processing Record 3 of Set 14 | mahebourg
# Processing Record 4 of Set 14 | puerto ayora
# Processing Record 5 of Set 14 | phangnga
# Processing Record 6 of Set 14 | meulaboh
# Processing Record 7 of Set 14 | mrakovo
# Processing Record 8 of Set 14 | narsaq
# Processing Record 9 of Set 14 | clyde river
# Processing Record 10 of Set 14 | vila franca do campo
# Processing Record 11 of Set 14 | port hedland
# Processing Record 12 of Set 14 | nouakchott
# Processing Record 13 of Set 14 | adrar
# Processing Record 14 of Set 14 | mudgee
# Processing Record 15 of Set 14 | butaritari
# Processing Record 16 of Set 14 | seoul
# Processing Record 17 of Set 14 | okha
# Processing Record 18 of Set 14 | pevek
# Processing Record 19 of Set 14 | hasaki
# Processing Record 20 of Set 14 | kavieng
# Processing Record 21 of Set 14 | dakar
# Processing Record 22 of Set 14 | porto-vecchio
# Processing Record 23 of Set 14 | borba
# Processing Record 24 of Set 14 | dingle
# Processing Record 25 of Set 14 | hobart
# Processing Record 26 of Set 14 | port hardy
# Processing Record 27 of Set 14 | henties bay
# Processing Record 28 of Set 14 | erdaojiang
# Processing Record 29 of Set 14 | tovarkovskiy
# Processing Record 30 of Set 14 | mys shmidta
# Processing Record 31 of Set 14 | diego de almagro
# Processing Record 32 of Set 14 | nishihara
# Processing Record 33 of Set 14 | easton
# Processing Record 34 of Set 14 | khatanga
# Processing Record 35 of Set 14 | rincon
# Processing Record 36 of Set 14 | songea
# Processing Record 37 of Set 14 | tungkang
# Processing Record 38 of Set 14 | nouadhibou
# Processing Record 39 of Set 14 | magugu
# Processing Record 40 of Set 14 | geraldton
# Processing Record 41 of Set 14 | saint anthony
# Processing Record 42 of Set 14 | guerrero negro
# Processing Record 43 of Set 14 | ribeira grande
# Processing Record 44 of Set 14 | nara
# Processing Record 45 of Set 14 | dikson
# Processing Record 46 of Set 14 | souillac
# Processing Record 47 of Set 14 | kjollefjord
# Processing Record 48 of Set 14 | port elizabeth
# Processing Record 49 of Set 14 | mount isa
# Processing Record 50 of Set 14 | amderma
# Processing Record 1 of Set 15 | tuktoyaktuk
# Processing Record 2 of Set 15 | tiarei
# Processing Record 3 of Set 15 | illoqqortoormiut
# Processing Record 4 of Set 15 | faanui
# Processing Record 5 of Set 15 | hirara
# Processing Record 6 of Set 15 | deputatskiy
# Processing Record 7 of Set 15 | oktyabrskiy
# Processing Record 8 of Set 15 | leh
# Processing Record 9 of Set 15 | broome
# Processing Record 10 of Set 15 | ahipara
# Processing Record 11 of Set 15 | abiy adi
# Processing Record 12 of Set 15 | mayumba
# Processing Record 13 of Set 15 | norman wells
# Processing Record 14 of Set 15 | saint-philippe
# Processing Record 15 of Set 15 | castro
# Processing Record 16 of Set 15 | nome
# Processing Record 17 of Set 15 | sao jose da coroa grande
# Processing Record 18 of Set 15 | evensk
# Processing Record 19 of Set 15 | pasighat
# Processing Record 20 of Set 15 | angoche
# Processing Record 21 of Set 15 | la paz
# Processing Record 22 of Set 15 | cap-aux-meules
# Processing Record 23 of Set 15 | monrovia
# Processing Record 24 of Set 15 | quatre cocos
# Processing Record 25 of Set 15 | mar del plata
# Processing Record 26 of Set 15 | whitehorse
# Processing Record 27 of Set 15 | bambous virieux
# Processing Record 28 of Set 15 | bambanglipuro
# Processing Record 29 of Set 15 | ginda
# Processing Record 30 of Set 15 | saint george
# Processing Record 31 of Set 15 | barrow
# Processing Record 32 of Set 15 | kapaa
# Processing Record 33 of Set 15 | georgetown
# Processing Record 34 of Set 15 | raudeberg
# Processing Record 35 of Set 15 | qandala
# Processing Record 36 of Set 15 | jizan
# Processing Record 37 of Set 15 | mullaitivu
# Processing Record 38 of Set 15 | tsevie
# Processing Record 39 of Set 15 | kharan
# Processing Record 40 of Set 15 | luancheng
# Processing Record 41 of Set 15 | oranjestad
# Processing Record 42 of Set 15 | manzil tamim
# Processing Record 43 of Set 15 | corleone
# Processing Record 44 of Set 15 | rungata
# Processing Record 45 of Set 15 | cidreira
# Processing Record 46 of Set 15 | belushya guba
# Processing Record 47 of Set 15 | faro
# Processing Record 48 of Set 15 | turayf
# Processing Record 49 of Set 15 | rizhao
# Processing Record 50 of Set 15 | taolanaro
# Processing Record 1 of Set 16 | toliary
# Processing Record 2 of Set 16 | nizhneyansk
# Processing Record 3 of Set 16 | saint-pierre
# Processing Record 4 of Set 16 | bandarbeyla
# Processing Record 5 of Set 16 | fortuna
# Processing Record 6 of Set 16 | half moon bay
# Processing Record 7 of Set 16 | maltahohe
# Processing Record 8 of Set 16 | bathsheba
# Processing Record 9 of Set 16 | bethel
# Processing Record 10 of Set 16 | mantua
# Processing Record 11 of Set 16 | new norfolk
# Processing Record 12 of Set 16 | vuktyl
# Processing Record 13 of Set 16 | oyama
# Processing Record 14 of Set 16 | alofi
# Processing Record 15 of Set 16 | kovdor
# Processing Record 16 of Set 16 | hamilton
# Processing Record 17 of Set 16 | valjala
# Processing Record 18 of Set 16 | lebu
# Processing Record 19 of Set 16 | daru
# Processing Record 20 of Set 16 | inuvik
# Processing Record 21 of Set 16 | naze
# Processing Record 22 of Set 16 | khani
# Processing Record 23 of Set 16 | watsa
# Processing Record 24 of Set 16 | yeppoon
# Processing Record 25 of Set 16 | marcona
# Processing Record 26 of Set 16 | kruisfontein
# Processing Record 27 of Set 16 | lisakovsk
# Processing Record 28 of Set 16 | ulaangom
# Processing Record 29 of Set 16 | nardaran
# Processing Record 30 of Set 16 | kenai
# Processing Record 31 of Set 16 | klaksvik
# Processing Record 32 of Set 16 | orange walk
# Processing Record 33 of Set 16 | boralday
# Processing Record 34 of Set 16 | torit
# Processing Record 35 of Set 16 | isangel
# Processing Record 36 of Set 16 | saint-junien
# Processing Record 37 of Set 16 | chuy
# Processing Record 38 of Set 16 | strezhevoy
# Processing Record 39 of Set 16 | warqla
# Processing Record 40 of Set 16 | upernavik
# Processing Record 41 of Set 16 | zaysan
# Processing Record 42 of Set 16 | asfi
# Processing Record 43 of Set 16 | sao filipe
# Processing Record 44 of Set 16 | qaanaaq
# Processing Record 45 of Set 16 | ancud
# Processing Record 46 of Set 16 | ambilobe
# Processing Record 47 of Set 16 | tigil
# Processing Record 48 of Set 16 | vila praia de ancora
# Processing Record 49 of Set 16 | baykit
# Processing Record 50 of Set 16 | mujiayingzi
# Processing Record 1 of Set 17 | primorsk
# Processing Record 2 of Set 17 | contamana
# Processing Record 3 of Set 17 | castro-urdiales
# Processing Record 4 of Set 17 | hilo
# Processing Record 5 of Set 17 | ilulissat
# Processing Record 6 of Set 17 | coihueco
# Processing Record 7 of Set 17 | gidole
# Processing Record 8 of Set 17 | lavrentiya
# Processing Record 9 of Set 17 | bronnoysund
# Processing Record 10 of Set 17 | carnarvon
# Processing Record 11 of Set 17 | itacarambi
# Processing Record 12 of Set 17 | rio claro
# Processing Record 13 of Set 17 | flinders
# Processing Record 14 of Set 17 | ussel
# Processing Record 15 of Set 17 | palabuhanratu
# Processing Record 16 of Set 17 | pisco
# Processing Record 17 of Set 17 | kanigoro
# Processing Record 18 of Set 17 | jamestown
# Processing Record 19 of Set 17 | iralaya
# Processing Record 20 of Set 17 | arraial do cabo
# Processing Record 21 of Set 17 | tonstad
# Processing Record 22 of Set 17 | kontagora
# Processing Record 23 of Set 17 | anahuac
# Processing Record 24 of Set 17 | carutapera
# Processing Record 25 of Set 17 | boa vista
# Processing Record 26 of Set 17 | cherskiy
# Processing Record 27 of Set 17 | el paujil
# Processing Record 28 of Set 17 | jalu
# Processing Record 29 of Set 17 | bafia
# Processing Record 30 of Set 17 | kaitangata
# Processing Record 31 of Set 17 | biograd na moru
# Processing Record 32 of Set 17 | umm durman
# Processing Record 33 of Set 17 | airai
# Processing Record 34 of Set 17 | kungurtug
# Processing Record 35 of Set 17 | coihaique
# Processing Record 36 of Set 17 | sakakah
# Processing Record 37 of Set 17 | kawanoe
# Processing Record 38 of Set 17 | east london
# Processing Record 39 of Set 17 | karaul
# Processing Record 40 of Set 17 | ulladulla
# Processing Record 41 of Set 17 | sao raimundo nonato
# Processing Record 42 of Set 17 | saldanha
# Processing Record 43 of Set 17 | anori
# Processing Record 44 of Set 17 | tuatapere
# Processing Record 45 of Set 17 | lorengau
# Processing Record 46 of Set 17 | laguna
# Processing Record 47 of Set 17 | ha tinh
# Processing Record 48 of Set 17 | dhidhdhoo
# Processing Record 49 of Set 17 | manthani
# Processing Record 50 of Set 17 | iqaluit
# Processing Record 1 of Set 18 | yertarskiy
# Processing Record 2 of Set 18 | kashi
# Processing Record 3 of Set 18 | kosh-agach
# Processing Record 4 of Set 18 | portland
# Processing Record 5 of Set 18 | tete
# Processing Record 6 of Set 18 | pontianak
# Processing Record 7 of Set 18 | dali
# Processing Record 8 of Set 18 | druzhnaya gorka
# Processing Record 9 of Set 18 | suleja
# Processing Record 10 of Set 18 | san felipe
# Processing Record 11 of Set 18 | hermitage
# Processing Record 12 of Set 18 | chokurdakh
# Processing Record 13 of Set 18 | nuuk
# Processing Record 14 of Set 18 | cosala
# Processing Record 15 of Set 18 | mwense
# Processing Record 16 of Set 18 | the valley
# Processing Record 17 of Set 18 | torbay
# Processing Record 18 of Set 18 | pointe michel
# Processing Record 19 of Set 18 | hernani
# Processing Record 20 of Set 18 | sudbury
# Processing Record 21 of Set 18 | olafsvik
# Processing Record 22 of Set 18 | non sang
# Processing Record 23 of Set 18 | tsihombe
# Processing Record 24 of Set 18 | kutum
# Processing Record 25 of Set 18 | itaituba
# Processing Record 26 of Set 18 | tacuarembo
# Processing Record 27 of Set 18 | taicheng
# Processing Record 28 of Set 18 | brae
# Processing Record 29 of Set 18 | rawson
# Processing Record 30 of Set 18 | karatau
# Processing Record 31 of Set 18 | igarka
# Processing Record 32 of Set 18 | constantine
# Processing Record 33 of Set 18 | bengkulu
# Processing Record 34 of Set 18 | severo-kurilsk
# Processing Record 35 of Set 18 | faya
# Processing Record 36 of Set 18 | ilhabela
# Processing Record 37 of Set 18 | ratodero
# Processing Record 38 of Set 18 | ormara
# Processing Record 39 of Set 18 | russell
# Processing Record 40 of Set 18 | wanning
# Processing Record 41 of Set 18 | luderitz
# Processing Record 42 of Set 18 | san jeronimo
# Processing Record 43 of Set 18 | sao paulo de olivenca
# Processing Record 44 of Set 18 | uglekamensk
# Processing Record 45 of Set 18 | northam
# Processing Record 46 of Set 18 | tasiilaq
# Processing Record 47 of Set 18 | fairbanks
# Processing Record 48 of Set 18 | kassala
# Processing Record 49 of Set 18 | arman
# Processing Record 50 of Set 18 | mackay
# Processing Record 1 of Set 19 | kegayli
# Processing Record 2 of Set 19 | beloha
# Processing Record 3 of Set 19 | balakhonovskoye
# Processing Record 4 of Set 19 | college
# Processing Record 5 of Set 19 | mopipi
# Processing Record 6 of Set 19 | tambovka
# Processing Record 7 of Set 19 | buala
# Processing Record 8 of Set 19 | san patricio
# Processing Record 9 of Set 19 | tucuman
# Processing Record 10 of Set 19 | kunming
# Processing Record 11 of Set 19 | penzance
# Processing Record 12 of Set 19 | kefalos
# Processing Record 13 of Set 19 | alegrete
# Processing Record 14 of Set 19 | north bend
# Processing Record 15 of Set 19 | mount gambier
# Processing Record 16 of Set 19 | talnakh
# Processing Record 17 of Set 19 | kerteh
# Processing Record 18 of Set 19 | bondo
# Processing Record 19 of Set 19 | darhan
# Processing Record 20 of Set 19 | ossora
# Processing Record 21 of Set 19 | masunga
# Processing Record 22 of Set 19 | prince albert
# Processing Record 23 of Set 19 | spalding
# Processing Record 24 of Set 19 | kahului
# Processing Record 25 of Set 19 | pascagoula
# Processing Record 26 of Set 19 | camana
# Processing Record 27 of Set 19 | yar-sale
# Processing Record 28 of Set 19 | dekar
# Processing Record 29 of Set 19 | touros
# Processing Record 30 of Set 19 | fevralsk
# Processing Record 31 of Set 19 | moranbah
# Processing Record 32 of Set 19 | jaguariuna
# Processing Record 33 of Set 19 | gat
# Processing Record 34 of Set 19 | channel-port aux basques
# Processing Record 35 of Set 19 | husavik
# Processing Record 36 of Set 19 | coquimbo
# Processing Record 37 of Set 19 | eirunepe
# Processing Record 38 of Set 19 | shangrao
# Processing Record 39 of Set 19 | batagay-alyta
# Processing Record 40 of Set 19 | pangody
# Processing Record 41 of Set 19 | los llanos de aridane
# Processing Record 42 of Set 19 | gwadar
# Processing Record 43 of Set 19 | nurota
# Processing Record 44 of Set 19 | mago
# Processing Record 45 of Set 19 | batemans bay
# Processing Record 46 of Set 19 | zhigansk
# Processing Record 47 of Set 19 | meybod
# Processing Record 48 of Set 19 | guarapari
# Processing Record 49 of Set 19 | patnos
# Processing Record 50 of Set 19 | hare bay
# Processing Record 1 of Set 20 | zaozerne
# Processing Record 2 of Set 20 | oistins
# Processing Record 3 of Set 20 | hithadhoo
# Processing Record 4 of Set 20 | nanortalik
# Processing Record 5 of Set 20 | pangnirtung
# Processing Record 6 of Set 20 | kavaratti
# Processing Record 7 of Set 20 | galesong
# Processing Record 8 of Set 20 | komsomolskiy
# Processing Record 9 of Set 20 | severnoye
# Processing Record 10 of Set 20 | waghai
# Processing Record 11 of Set 20 | berlevag
# Processing Record 12 of Set 20 | ribeira brava
# Processing Record 13 of Set 20 | vardo
# Processing Record 14 of Set 20 | quebo
# Processing Record 15 of Set 20 | menongue
# Processing Record 16 of Set 20 | luwuk
# Processing Record 17 of Set 20 | point pleasant
# Processing Record 18 of Set 20 | pa sang
# Processing Record 19 of Set 20 | fethiye
# Processing Record 20 of Set 20 | svetlogorsk
# Processing Record 21 of Set 20 | arlit
# Processing Record 22 of Set 20 | chapleau
# Processing Record 23 of Set 20 | saleaula
# Processing Record 24 of Set 20 | qarayeri
# Processing Record 25 of Set 20 | sao joao da barra
# Processing Record 26 of Set 20 | kasulu
# Processing Record 27 of Set 20 | puerto ayacucho
# Processing Record 28 of Set 20 | springbok
# Processing Record 29 of Set 20 | tabuk
# Processing Record 30 of Set 20 | sao mateus
# Processing Record 31 of Set 20 | la troncal
# Processing Record 32 of Set 20 | yarmouth
# Processing Record 33 of Set 20 | waingapu
# Processing Record 34 of Set 20 | longyearbyen
# Processing Record 35 of Set 20 | murud
# Processing Record 36 of Set 20 | pervomayskoye
# Processing Record 37 of Set 20 | bemidji
# Processing Record 38 of Set 20 | burica
# Processing Record 39 of Set 20 | visby
# Processing Record 40 of Set 20 | beidao
# Processing Record 41 of Set 20 | bumba
# Processing Record 42 of Set 20 | yumen
# Processing Record 43 of Set 20 | mount darwin
# Processing Record 44 of Set 20 | tessalit
# Processing Record 45 of Set 20 | ostrovnoy
# Processing Record 46 of Set 20 | popondetta
# Processing Record 47 of Set 20 | liverpool
# Processing Record 48 of Set 20 | esperance
# Processing Record 49 of Set 20 | muros
# Processing Record 50 of Set 20 | los alamos
# Processing Record 1 of Set 21 | bahia blanca
# Processing Record 2 of Set 21 | codrington
# Processing Record 3 of Set 21 | grindavik
# Processing Record 4 of Set 21 | salme
# Processing Record 5 of Set 21 | skibbereen
# Processing Record 6 of Set 21 | irati
# Processing Record 7 of Set 21 | toamasina
# Processing Record 8 of Set 21 | dukat
# Processing Record 9 of Set 21 | tarudant
# Processing Record 10 of Set 21 | padang
# Processing Record 11 of Set 21 | taft
# Processing Record 12 of Set 21 | walvis bay
# Processing Record 13 of Set 21 | ketchikan
# Processing Record 14 of Set 21 | palanga
# Processing Record 15 of Set 21 | kristinehamn
# Processing Record 16 of Set 21 | tumannyy
# Processing Record 17 of Set 21 | denpasar
# Processing Record 18 of Set 21 | amuntai
# Processing Record 19 of Set 21 | calbiga
# Processing Record 20 of Set 21 | songjianghe
# Processing Record 21 of Set 21 | hunza
# Processing Record 22 of Set 21 | karratha
# Processing Record 23 of Set 21 | avera
# Processing Record 24 of Set 21 | neuquen
# Processing Record 25 of Set 21 | grand river south east
# Processing Record 26 of Set 21 | kitui
# Processing Record 27 of Set 21 | waipawa
# Processing Record 28 of Set 21 | acajutla
# Processing Record 29 of Set 21 | zhanatas
# Processing Record 30 of Set 21 | sitka
# Processing Record 31 of Set 21 | kisangani
# Processing Record 32 of Set 21 | maniitsoq
# Processing Record 33 of Set 21 | morehead
# Processing Record 34 of Set 21 | vao
# Processing Record 35 of Set 21 | krasnoselkup
# Processing Record 36 of Set 21 | cabo san lucas
# Processing Record 37 of Set 21 | merauke
# Processing Record 38 of Set 21 | coos bay
# Processing Record 39 of Set 21 | rio grande
# Processing Record 40 of Set 21 | davila
# Processing Record 41 of Set 21 | gornopravdinsk
# Processing Record 42 of Set 21 | beira
# Processing Record 43 of Set 21 | mayo
# Processing Record 44 of Set 21 | ambodifototra
# Processing Record 45 of Set 21 | wolgast
# Processing Record 46 of Set 21 | namatanai
# Processing Record 47 of Set 21 | aldergrove
# Processing Record 48 of Set 21 | luanda
# Processing Record 49 of Set 21 | sturgis
# Processing Record 50 of Set 21 | sabha
# Processing Record 1 of Set 22 | lakatoro
# Processing Record 2 of Set 22 | henderson
# Processing Record 3 of Set 22 | omboue
# Processing Record 4 of Set 22 | ilorin
# Processing Record 5 of Set 22 | lompoc
# Processing Record 6 of Set 22 | atar
# Processing Record 7 of Set 22 | aklavik
# Processing Record 8 of Set 22 | bairiki
# Processing Record 9 of Set 22 | iranshahr
# Processing Record 10 of Set 22 | attawapiskat
# Processing Record 11 of Set 22 | hambantota
# Processing Record 12 of Set 22 | marzuq
# Processing Record 13 of Set 22 | itapirapua
# Processing Record 14 of Set 22 | vaitupu
# Processing Record 15 of Set 22 | sao gabriel da cachoeira
# Processing Record 16 of Set 22 | vostok
# Processing Record 17 of Set 22 | swan river
# Processing Record 18 of Set 22 | manokwari
# Processing Record 19 of Set 22 | cayenne
# Processing Record 20 of Set 22 | lasa
# Processing Record 21 of Set 22 | samalaeulu
# Processing Record 22 of Set 22 | huancavelica
# Processing Record 23 of Set 22 | kolimvari
# Processing Record 24 of Set 22 | soyo
# Processing Record 25 of Set 22 | victoria
# Processing Record 26 of Set 22 | maceio
# Processing Record 27 of Set 22 | anchorage
# Processing Record 28 of Set 22 | lexington park
# Processing Record 29 of Set 22 | caala
# Processing Record 30 of Set 22 | la ronge
# Processing Record 31 of Set 22 | kulhudhuffushi
# Processing Record 32 of Set 22 | bilma
# Processing Record 33 of Set 22 | filadelfia
# Processing Record 34 of Set 22 | loa janan
# Processing Record 35 of Set 22 | leningradskiy
# Processing Record 36 of Set 22 | mongo
# Processing Record 37 of Set 22 | guatire
# Processing Record 38 of Set 22 | loandjili
# Processing Record 39 of Set 22 | warrington
# Processing Record 40 of Set 22 | novobirilyussy
# Processing Record 41 of Set 22 | asau
# Processing Record 42 of Set 22 | tutin
# Processing Record 43 of Set 22 | moiyabana
# Processing Record 44 of Set 22 | voi
# Processing Record 45 of Set 22 | taltal
# Processing Record 46 of Set 22 | ventanas
# Processing Record 47 of Set 22 | ust-omchug
# Processing Record 48 of Set 22 | nelson bay
# Processing Record 49 of Set 22 | bonfim
# Processing Record 50 of Set 22 | richards bay
# Processing Record 1 of Set 23 | talaya
# Processing Record 2 of Set 23 | tucano
# Processing Record 3 of Set 23 | sunbury
# Processing Record 4 of Set 23 | bowen
# Processing Record 5 of Set 23 | catamarca
# Processing Record 6 of Set 23 | maghama
# Processing Record 7 of Set 23 | kashima
# Processing Record 8 of Set 23 | pardina
# Processing Record 9 of Set 23 | lagoa
# Processing Record 10 of Set 23 | canton
# Processing Record 11 of Set 23 | champerico
# Processing Record 12 of Set 23 | puerto escondido
# Processing Record 13 of Set 23 | salalah
# Processing Record 14 of Set 23 | tulum
# Processing Record 15 of Set 23 | marshfield
# Processing Record 16 of Set 23 | akureyri
# Processing Record 17 of Set 23 | ondjiva
# Processing Record 18 of Set 23 | saint-francois
# Processing Record 19 of Set 23 | zhangye
# Processing Record 20 of Set 23 | katsuura
# Processing Record 21 of Set 23 | hiroshima
# Processing Record 22 of Set 23 | imbituba
# Processing Record 23 of Set 23 | andilamena
# Processing Record 24 of Set 23 | san cristobal
# Processing Record 25 of Set 23 | malindi
# Processing Record 26 of Set 23 | tagusao
# Processing Record 27 of Set 23 | port keats
# Processing Record 28 of Set 23 | heihe
# Processing Record 29 of Set 23 | plainview
# Processing Record 30 of Set 23 | rio verde de mato grosso
# Processing Record 31 of Set 23 | gijon
# Processing Record 32 of Set 23 | buin
# Processing Record 33 of Set 23 | malwan
# Processing Record 34 of Set 23 | clyde
# Processing Record 35 of Set 23 | juneau
# Processing Record 36 of Set 23 | peterhead
# Processing Record 37 of Set 23 | beisfjord
# Processing Record 38 of Set 23 | galveston
# Processing Record 39 of Set 23 | rundu
# Processing Record 40 of Set 23 | kamenka
# Processing Record 41 of Set 23 | paita
# Processing Record 42 of Set 23 | princeton
# Processing Record 43 of Set 23 | utiroa
# Processing Record 44 of Set 23 | oussouye
# Processing Record 45 of Set 23 | la peca
# Processing Record 46 of Set 23 | poum
# Processing Record 47 of Set 23 | taoudenni
# Processing Record 48 of Set 23 | wampusirpi
# Processing Record 49 of Set 23 | axim
# Processing Record 50 of Set 23 | moose factory
# Processing Record 1 of Set 24 | dunedin
# Processing Record 2 of Set 24 | honiara
# Processing Record 3 of Set 24 | mackenzie
# Processing Record 4 of Set 24 | diffa
# Processing Record 5 of Set 24 | karatsu
# Processing Record 6 of Set 24 | muroto
# Processing Record 7 of Set 24 | vila
# Processing Record 8 of Set 24 | lubango
# Processing Record 9 of Set 24 | lipin bor
# Processing Record 10 of Set 24 | okhotsk
# Processing Record 11 of Set 24 | tabialan
# Processing Record 12 of Set 24 | mareeba
# Processing Record 13 of Set 24 | dubbo
# Processing Record 14 of Set 24 | jiayuguan
# Processing Record 15 of Set 24 | kaabong
# Processing Record 16 of Set 24 | lata
# Processing Record 17 of Set 24 | pangoa
# Processing Record 18 of Set 24 | auki
# Processing Record 19 of Set 24 | newport
# Processing Record 20 of Set 24 | khonuu
# Processing Record 21 of Set 24 | horice
# Processing Record 22 of Set 24 | pathein
# Processing Record 23 of Set 24 | chagda
# Processing Record 24 of Set 24 | joshimath
# Processing Record 25 of Set 24 | kankaanpaa
# Processing Record 26 of Set 24 | saint-ambroise
# Processing Record 27 of Set 24 | a coruna
# Processing Record 28 of Set 24 | safaqis
# Processing Record 29 of Set 24 | maldonado
# Processing Record 30 of Set 24 | zarate
# Processing Record 31 of Set 24 | marienburg
# Processing Record 32 of Set 24 | talladega
# Processing Record 33 of Set 24 | rize
# Processing Record 34 of Set 24 | mvangue
# Processing Record 35 of Set 24 | lokosovo
# Processing Record 36 of Set 24 | iquitos
# Processing Record 37 of Set 24 | houma
# Processing Record 38 of Set 24 | kemijarvi
# Processing Record 39 of Set 24 | sault sainte marie
# Processing Record 40 of Set 24 | doctor pedro p. pena
# Processing Record 41 of Set 24 | kushiro
# Processing Record 42 of Set 24 | tibati
# Processing Record 43 of Set 24 | juba
# Processing Record 44 of Set 24 | paamiut
# Processing Record 45 of Set 24 | tucuma
# Processing Record 46 of Set 24 | caravelas
# Processing Record 47 of Set 24 | loiza
# Processing Record 48 of Set 24 | vigrestad
# Processing Record 49 of Set 24 | norsup
# Processing Record 50 of Set 24 | xuanwu
# Processing Record 1 of Set 25 | namie
# Processing Record 2 of Set 25 | mezen
# Processing Record 3 of Set 25 | port lincoln
# Processing Record 4 of Set 25 | waikuku
# Processing Record 5 of Set 25 | rexburg
# Processing Record 6 of Set 25 | lac-megantic

# %%
# Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Lac-Megantic  45.5834 -70.8823     73.22        97         100        6.22
#
#   Country                 Date
# 0      CA  2021-08-07 23:18:18

# %%
#Recall that to reorder the columns, we assign a variable to an array of the columns in the order we want them to appear:
#new_column_order = ["column2", "column4", "column1"]
new_column_order = ["City", "Country", 'Date', 'Lat', 'Lng', "Max Temp", 'Humidity','Cloudiness','Wind Speed']

# %%
df = city_data_df[new_column_order]
df
# Out:
#            City Country                 Date      Lat      Lng  Max Temp  \
# 0  Lac-Megantic      CA  2021-08-07 23:18:18  45.5834 -70.8823     73.22
#
#    Humidity  Cloudiness  Wind Speed
# 0        97         100        6.22

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1628378480.717744

# %%
time.strftime("%x")
# Out:
# '08/07/21'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig3.png")
# Show plot.
plt.show()
