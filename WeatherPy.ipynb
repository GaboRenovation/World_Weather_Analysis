# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# In the next cell, we'll add the code that generates the latitudes and longitudes, but first, they need to be stored so that we can access them later. Since we are creating arrays of latitudes and longitudes, we'll declare each array as a variable.
#
# In the next cell, add the following code that we used to generate the random latitudes. Also, we'll create a similar code snippet that will generate longitudes. To ensure enough latitudes and longitudes, we'll start with 1,500. In addition, we'll pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# When we run this cell, the output is a zip object in memory.

# %% [markdown]
# The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple. If there are 1,500 latitudes and longitudes, there will be 1,500 tuples of paired latitudes and longitudes, where each latitude and longitude in a tuple can be accessed by the index of 0 and 1, respectively.

# %% [markdown]
# In a new Jupyter Notebook file called API_practice.ipynb, add the following lists and pack them into the zipped tuple. Then, run the cell.
#
# # Create a practice set of random latitude and longitude combinations.
# x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
# y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
# coordinates = zip(x, y)
#
# In a new cell, display the coordinate pairs with the following code.
#
# # Use the tuple() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])
#
# When we run the cell above, the output is ordered pairs of our x and y coordinates.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
#     You can only unzip a zipped tuple once before it is removed from the computer's         memory. Make sure you unzip the latitudes and longitudes into the coordinates list            before moving on.
#
# Now that we have our ordered pairs of latitudes and longitudes in a list, we can iterate through the list of tuples and find the nearest city to those coordinates.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %% [markdown]
# a for loop that will do the following:
#
#     Iterate through the coordinates' zipped tuple.
#
#     Use citipy.nearest_city() and inside the parentheses of nearest_city(), add the latitude and longitude in this format: coordinate[0], coordinate[1].
#
#     To print the city name, chain the city_name to the nearest_city() function.
#
#     To print the country name, chain the country_code to the nearest_city() function.

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# passo de camaragibe br
# moratuwa lk
# ossora ru
# atuona pf
# albany au
# belushya guba ru
# rikitea pf
# victoria sc
# lebu cl
# puerto ayora ec
# provideniya ru
# shingu jp
# busselton au
# okahandja na
# punta arenas cl
# college us
# cap malheureux mu
# punta arenas cl
# nikolsk ru
# rikitea pf
# ushuaia ar
# jacobina br
# saskylakh ru
# rawson ar
# port blair in
# kapuskasing ca
# henties bay na
# bredasdorp za
# maumere id
# santiago del estero ar
# albany au
# hermanus za
# bluff nz
# bathsheba bb
# hermanus za
# east london za
# tasiilaq gl
# rikitea pf
# dikson ru
# miramar mx
# san cristobal ec
# fortuna us
# cap malheureux mu
# rawson ar
# bluff nz
# alyangula au
# puerto ayora ec
# souillac mu
# illoqqortoormiut gl
# barentsburg sj
# chokurdakh ru
# barrow us
# bluff nz
# pucallpa pe
# avarua ck
# acapulco mx
# lorengau pg
# cape town za
# ushuaia ar
# hoi an vn
# georgetown sh
# busselton au
# punta arenas cl
# taolanaro mg
# hobart au
# atuona pf
# moindou nc
# palencia es
# taolanaro mg
# khatanga ru
# haskovo bg
# chardara kz
# punta arenas cl
# bonavista ca
# dwarka in
# bredasdorp za
# qaanaaq gl
# kapaa us
# castro cl
# sompeta in
# butaritari ki
# pokhara np
# san quintin mx
# sur om
# saskylakh ru
# samusu ws
# airai pw
# pimentel pe
# airai pw
# bredasdorp za
# barentu er
# vaini to
# atuona pf
# kamenka ru
# wexford ie
# kodiak us
# tautira pf
# vila velha br
# bluff nz
# illoqqortoormiut gl
# westport nz
# longyearbyen sj
# mandalgovi mn
# ushuaia ar
# huarmey pe
# airai pw
# mamallapuram in
# grants us
# russell nz
# saint-philippe re
# emirdag tr
# rikitea pf
# bethel us
# new norfolk au
# ushuaia ar
# belushya guba ru
# mahebourg mu
# atuona pf
# saint-georges gf
# rikitea pf
# mehamn no
# harper lr
# klaksvik fo
# kaitangata nz
# san policarpo ph
# los algarrobos pa
# chokurdakh ru
# hermanus za
# rikitea pf
# emerald au
# hithadhoo mv
# upernavik gl
# atuona pf
# pascagoula us
# moose factory ca
# ushuaia ar
# taltal cl
# barrow us
# geraldton au
# chokurdakh ru
# tuatapere nz
# kapaa us
# mar del plata ar
# benito soliven ph
# shingu jp
# taybad ir
# maniitsoq gl
# bredasdorp za
# chokurdakh ru
# ponta do sol cv
# mys shmidta ru
# port elizabeth za
# busselton au
# dikson ru
# illoqqortoormiut gl
# kapaa us
# ushuaia ar
# ushuaia ar
# cherskiy ru
# saint-philippe re
# cape town za
# tasiilaq gl
# esperance au
# mataura pf
# broome au
# barrow us
# torbay ca
# nizhneyansk ru
# hamilton bm
# isangel vu
# punta arenas cl
# aklavik ca
# longyearbyen sj
# hasaki jp
# sahuaripa mx
# georgetown sh
# butaritari ki

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
         
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 586

# %%
import requests
requests.__version__
# Out:
# '2.25.1'

# %%
# Import the API key.
from config import weather_api_key

# %% [markdown]
# ------------------------------------------------------
#
# Borrar   + weather_api_key
# ------------------------------------------------------
# ------------------------------------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# al final se incluyó    + weather_api_key

# %% [markdown]
# ------------------------------------------------------
# no olvidar borrar
# weather_api_key
# ------------------------------------------------------
# ------------------------------------------------------

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# a Boston le falta una 'o' por ello arroja el error 404 que significa
# que la URL no fue encontrada
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %% [markdown]
# When we run this cell the output is "<Response [200]>."
#
#
# When we receive a valid response from the server, we have to decide on the data format. The options are text, JSON, XML, or HTML format. We can apply the format attributes to get the data into a useful format to parse.
#
# One format that provides a preview of the JSON data is the text attribute. Let's get the content for the Boston weather data using the following code.

# %%
# One format that provides a preview of the JSON data is the text attribute. 
# Let's get the content for the Boston weather data using the following code.
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":75.51,"feels_like":76.19,"temp_min":71.1,"temp_max":78.17,"pressure":1016,"humidity":73},"visibility":10000,"wind":{"speed":4,"deg":297,"gust":11.01},"clouds":{"all":100},"dt":1628390707,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1628329394,"sunset":1628380606},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 75.51,
#   'feels_like': 76.19,
#   'temp_min': 71.1,
#   'temp_max': 78.17,
#   'pressure': 1016,
#   'humidity': 73},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 297, 'gust': 11.01},
#  'clouds': {'all': 100},
#  'dt': 1628390707,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1628329394,
#   'sunset': 1628380606},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4b6a64249f0a93f971d6379291fb5960&q=Boston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 75.51,
#   'feels_like': 76.19,
#   'temp_min': 71.1,
#   'temp_max': 78.17,
#   'pressure': 1016,
#   'humidity': 73},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 297, 'gust': 11.01},
#  'clouds': {'all': 100},
#  'dt': 1628390707,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1628329394,
#   'sunset': 1628380606},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# _________________
# In a new cell, let's assign a variable to the city_weather.json() data to the variable "boston_data" and run the cell

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1628329394,
#  'sunset': 1628380606}

# %%
boston_data['sys']['country']
# Out:
# 'US'

# %%
# to retrieve the weather data
boston_data["dt"]
# Out:
# 1628390707

# %%
boston_data['coord']['lat']
# Out:
# 42.3584

# %%
boston_data['main']['temp_max']
# Out:
# 78.17

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 78.17 73 100 4

# %% [markdown]
# ________________
# **  Viene de API practice
# ----------------------
# ----------------------

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %% [markdown]
# ________________
# **  Viene de Random Numbers
# ----------------------
# ----------------------

# %%
# Import the random module.
import random

# %%
random.random()
#this method will launch a number between 0 and 1
# Out:
# 0.629695137791096

# %%
random.randint(-90,90)
#this method will launch an Integer Number between -90 and 90
# Out:
# 61

# %%
random.randrange(-9,9,2)
#this method will launch a number between -9 and 9 with intervals of 2
# Out:
# -3

# %%
random.uniform(-10,10)
#this method will launch a number between -10 and 10 including float (decimals)
# Out:
# 4.8182210822730624

# %%
random_number = random.randint(-90,89) + random.random()
random_number
# Out:
# 79.25994983024432

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
y = 1
longitudes = []
while y < 11:
    random_long = random.randint(-180, 180) + random.random()
    longitudes.append(random_long)
    y += 1

# %%
random.randrange(-90, 90, step=1)
# Out:
# 46

# %%
# now using method  randrange(0,0, step=1)

z = 1
lon2 = []
while z < 11:
    random_lon2 = random.randrange(-180, 180, step=3) + random.random()
    lon2.append(random_lon2)
    z += 1

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -32.85152862028006

# %%
np.random.uniform(low=-90, high=90)
# Out:
# 34.36436921803485

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([-78.75585528,  30.10955187,  27.10420085,  59.22860836,
#        -69.68049629,  26.60618371,  -5.97297171, -34.868534  ,
#         47.47213413,  58.99931506,  44.74161295, -11.05758823,
#        -64.56525643,  -6.7921696 ,  57.60340952, -24.53173713,
#         59.09876022, -57.90967918,  65.05571577,   6.46069835,
#        -81.99241612, -21.76433471,  26.18205319, -82.704886  ,
#        -47.52006175, -78.73865161, -50.16021885,  28.85937116,
#          9.16419157,  63.80089469,  67.62666155, -25.23214394,
#        -68.06188966,  31.35036781,  -7.29606313,  44.41127315,
#         22.1614762 , -58.10626822,   6.65913893, -28.99852175,
#        -14.58206679,  87.046719  , -48.21769082, -30.11868981,
#         58.94903437, -33.98623473,  43.14276936,  42.86563406,
#        -10.41141012, -56.19866408])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 18.6 µs ± 74.1 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.7 ms ± 30.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ------------------------------------------
# Convert the Date Timestamp
# ------------------------------------------
# ------------------------------------------

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 8, 8, 2, 45, 7)

# %% [markdown]
# We can convert this datetime format to 2019-10-21 17:24:35 using the Python string format method strftime() and adding how we want the string to look inside the parentheses. In our case, we would use strftime('%Y-%m-%d %H:%M:%S').

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-08-08 02:45:07'

# %% [markdown]
# 1. Import our dependencies and initialize counters and an empty list that will hold the weather data.
# 2. Loop through the cities list.
# 3. Group the cities in sets of 50 to log the process as we find the weather data for each city.
#     - Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# 4. Build the city_url or endpoint for each city.
# 5. Log the URL and the record and set numbers.
# 6. Make an API request for each city.
# 7. Parse the JSON weather data for the following:
#    - City, country, and date
#    - Latitude and longitude
#    - Maximum temperature
#    - Humidity
#    - Cloudiness
#    - Wind speed
# 8. Add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
city_data
# Out:
# []

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 12 | passo de camaragibe
# Processing Record 2 of Set 12 | moratuwa
# Processing Record 3 of Set 12 | ossora
# Processing Record 4 of Set 12 | atuona
# Processing Record 5 of Set 12 | albany
# Processing Record 6 of Set 12 | belushya guba
# Processing Record 7 of Set 12 | rikitea
# Processing Record 8 of Set 12 | victoria
# Processing Record 9 of Set 12 | lebu
# Processing Record 10 of Set 12 | puerto ayora
# Processing Record 11 of Set 12 | provideniya
# Processing Record 12 of Set 12 | shingu
# Processing Record 13 of Set 12 | busselton
# Processing Record 14 of Set 12 | okahandja
# Processing Record 15 of Set 12 | punta arenas
# Processing Record 16 of Set 12 | college
# Processing Record 17 of Set 12 | cap malheureux
# Processing Record 18 of Set 12 | nikolsk
# Processing Record 19 of Set 12 | ushuaia
# Processing Record 20 of Set 12 | jacobina
# Processing Record 21 of Set 12 | saskylakh
# Processing Record 22 of Set 12 | rawson
# Processing Record 23 of Set 12 | port blair
# Processing Record 24 of Set 12 | kapuskasing
# Processing Record 25 of Set 12 | henties bay
# Processing Record 26 of Set 12 | bredasdorp
# Processing Record 27 of Set 12 | maumere
# Processing Record 28 of Set 12 | santiago del estero
# Processing Record 29 of Set 12 | hermanus
# Processing Record 30 of Set 12 | bluff
# Processing Record 31 of Set 12 | bathsheba
# Processing Record 32 of Set 12 | east london
# Processing Record 33 of Set 12 | tasiilaq
# Processing Record 34 of Set 12 | dikson
# Processing Record 35 of Set 12 | miramar
# Processing Record 36 of Set 12 | san cristobal
# Processing Record 37 of Set 12 | fortuna
# Processing Record 38 of Set 12 | alyangula
# Processing Record 39 of Set 12 | souillac
# Processing Record 40 of Set 12 | illoqqortoormiut
# Processing Record 41 of Set 12 | barentsburg
# Processing Record 42 of Set 12 | chokurdakh
# Processing Record 43 of Set 12 | barrow
# Processing Record 44 of Set 12 | pucallpa
# Processing Record 45 of Set 12 | avarua
# Processing Record 46 of Set 12 | acapulco
# Processing Record 47 of Set 12 | lorengau
# Processing Record 48 of Set 12 | cape town
# Processing Record 49 of Set 12 | hoi an
# Processing Record 50 of Set 12 | georgetown
# Processing Record 1 of Set 13 | taolanaro
# Processing Record 2 of Set 13 | hobart
# Processing Record 3 of Set 13 | moindou
# Processing Record 4 of Set 13 | palencia
# Processing Record 5 of Set 13 | khatanga
# Processing Record 6 of Set 13 | haskovo
# Processing Record 7 of Set 13 | chardara
# Processing Record 8 of Set 13 | bonavista
# Processing Record 9 of Set 13 | dwarka
# Processing Record 10 of Set 13 | qaanaaq
# Processing Record 11 of Set 13 | kapaa
# Processing Record 12 of Set 13 | castro
# Processing Record 13 of Set 13 | sompeta
# Processing Record 14 of Set 13 | butaritari
# Processing Record 15 of Set 13 | pokhara
# Processing Record 16 of Set 13 | san quintin
# Processing Record 17 of Set 13 | sur
# Processing Record 18 of Set 13 | samusu
# Processing Record 19 of Set 13 | airai
# Processing Record 20 of Set 13 | pimentel
# Processing Record 21 of Set 13 | barentu
# Processing Record 22 of Set 13 | vaini
# Processing Record 23 of Set 13 | kamenka
# Processing Record 24 of Set 13 | jamestown
# Processing Record 25 of Set 13 | matara
# Processing Record 26 of Set 13 | mehkar
# Processing Record 27 of Set 13 | den helder
# Processing Record 28 of Set 13 | shediac
# Processing Record 29 of Set 13 | mataura
# Processing Record 30 of Set 13 | arraial do cabo
# Processing Record 31 of Set 13 | mitsamiouli
# Processing Record 32 of Set 13 | fairbanks
# Processing Record 33 of Set 13 | progreso
# Processing Record 34 of Set 13 | aripuana
# Processing Record 35 of Set 13 | vicuna
# Processing Record 36 of Set 13 | evensk
# Processing Record 37 of Set 13 | ocampo
# Processing Record 38 of Set 13 | saint george
# Processing Record 39 of Set 13 | marsabit
# Processing Record 40 of Set 13 | saint-philippe
# Processing Record 41 of Set 13 | hambantota
# Processing Record 42 of Set 13 | abu samrah
# Processing Record 43 of Set 13 | faanui
# Processing Record 44 of Set 13 | minab
# Processing Record 45 of Set 13 | vila franca do campo
# Processing Record 46 of Set 13 | tuktoyaktuk
# Processing Record 47 of Set 13 | alofi
# Processing Record 48 of Set 13 | talnakh
# Processing Record 49 of Set 13 | mount isa
# Processing Record 50 of Set 13 | mataram
# Processing Record 1 of Set 14 | grindavik
# Processing Record 2 of Set 14 | safranbolu
# Processing Record 3 of Set 14 | kleck
# Processing Record 4 of Set 14 | aklavik
# Processing Record 5 of Set 14 | nizhneyansk
# Processing Record 6 of Set 14 | qasigiannguit
# Processing Record 7 of Set 14 | new norfolk
# Processing Record 8 of Set 14 | dunedin
# Processing Record 9 of Set 14 | santa marta
# Processing Record 10 of Set 14 | nanortalik
# Processing Record 11 of Set 14 | aykhal
# Processing Record 12 of Set 14 | pevek
# Processing Record 13 of Set 14 | saldanha
# Processing Record 14 of Set 14 | carevo
# Processing Record 15 of Set 14 | hilo
# Processing Record 16 of Set 14 | grand river south east
# Processing Record 17 of Set 14 | hami
# Processing Record 18 of Set 14 | guiglo
# Processing Record 19 of Set 14 | dolbeau
# Processing Record 20 of Set 14 | mgandu
# Processing Record 21 of Set 14 | huarmey
# Processing Record 22 of Set 14 | kruisfontein
# Processing Record 23 of Set 14 | atar
# Processing Record 24 of Set 14 | leningradskiy
# Processing Record 25 of Set 14 | nikolskoye
# Processing Record 26 of Set 14 | diego de almagro
# Processing Record 27 of Set 14 | ilulissat
# Processing Record 28 of Set 14 | port alfred
# Processing Record 29 of Set 14 | attawapiskat
# Processing Record 30 of Set 14 | orlik
# Processing Record 31 of Set 14 | bethel
# Processing Record 32 of Set 14 | iqaluit
# Processing Record 33 of Set 14 | anqiu
# Processing Record 34 of Set 14 | eenhana
# Processing Record 35 of Set 14 | atagay
# Processing Record 36 of Set 14 | hakkari
# Processing Record 37 of Set 14 | belyy yar
# Processing Record 38 of Set 14 | torbay
# Processing Record 39 of Set 14 | taksimo
# Processing Record 40 of Set 14 | amderma
# Processing Record 41 of Set 14 | morristown
# Processing Record 42 of Set 14 | mys shmidta
# Processing Record 43 of Set 14 | melipilla
# Processing Record 44 of Set 14 | sambava
# Processing Record 45 of Set 14 | mozarlandia
# Processing Record 46 of Set 14 | maragogi
# Processing Record 47 of Set 14 | telde
# Processing Record 48 of Set 14 | japura
# Processing Record 49 of Set 14 | at-bashi
# Processing Record 50 of Set 14 | ovalle
# Processing Record 1 of Set 15 | hofn
# Processing Record 2 of Set 15 | yumen
# Processing Record 3 of Set 15 | puerto colombia
# Processing Record 4 of Set 15 | urdzhar
# Processing Record 5 of Set 15 | sabang
# Processing Record 6 of Set 15 | luceville
# Processing Record 7 of Set 15 | saint johnsbury
# Processing Record 8 of Set 15 | winnemucca
# Processing Record 9 of Set 15 | gurgan
# Processing Record 10 of Set 15 | yellowknife
# Processing Record 11 of Set 15 | beloha
# Processing Record 12 of Set 15 | geraldton
# Processing Record 13 of Set 15 | ornskoldsvik
# Processing Record 14 of Set 15 | klaksvik
# Processing Record 15 of Set 15 | bokspits
# Processing Record 16 of Set 15 | vaitupu
# Processing Record 17 of Set 15 | iwanai
# Processing Record 18 of Set 15 | namibe
# Processing Record 19 of Set 15 | belmonte
# Processing Record 20 of Set 15 | pouebo
# Processing Record 21 of Set 15 | haines junction
# Processing Record 22 of Set 15 | constitucion
# Processing Record 23 of Set 15 | russell
# Processing Record 24 of Set 15 | moron
# Processing Record 25 of Set 15 | mar del plata
# Processing Record 26 of Set 15 | port elizabeth
# Processing Record 27 of Set 15 | guntur
# Processing Record 28 of Set 15 | tsihombe
# Processing Record 29 of Set 15 | ngunguru
# Processing Record 30 of Set 15 | paoua
# Processing Record 31 of Set 15 | saint-louis
# Processing Record 32 of Set 15 | mengcheng
# Processing Record 33 of Set 15 | andrelandia
# Processing Record 34 of Set 15 | madimba
# Processing Record 35 of Set 15 | colonelganj
# Processing Record 36 of Set 15 | ust-tsilma
# Processing Record 37 of Set 15 | sorvag
# Processing Record 38 of Set 15 | luau
# Processing Record 39 of Set 15 | nioro
# Processing Record 40 of Set 15 | kasimov
# Processing Record 41 of Set 15 | grand-lahou
# Processing Record 42 of Set 15 | qaqortoq
# Processing Record 43 of Set 15 | ostrovnoy
# Processing Record 44 of Set 15 | la vergne
# Processing Record 45 of Set 15 | mahebourg
# Processing Record 46 of Set 15 | takoradi
# Processing Record 47 of Set 15 | margate
# Processing Record 48 of Set 15 | sao joao da barra
# Processing Record 49 of Set 15 | awjilah
# Processing Record 50 of Set 15 | rosarito
# Processing Record 1 of Set 16 | ambovombe
# Processing Record 2 of Set 16 | ati
# Processing Record 3 of Set 16 | bur gabo
# Processing Record 4 of Set 16 | pacific grove
# Processing Record 5 of Set 16 | port keats
# Processing Record 6 of Set 16 | clyde river
# Processing Record 7 of Set 16 | thompson
# Processing Record 8 of Set 16 | araouane
# Processing Record 9 of Set 16 | simao
# Processing Record 10 of Set 16 | sannois
# Processing Record 11 of Set 16 | katangli
# Processing Record 12 of Set 16 | gimli
# Processing Record 13 of Set 16 | isangel
# Processing Record 14 of Set 16 | atambua
# Processing Record 15 of Set 16 | derzhavinsk
# Processing Record 16 of Set 16 | hithadhoo
# Processing Record 17 of Set 16 | safaga
# Processing Record 18 of Set 16 | berlevag
# Processing Record 19 of Set 16 | gnjilane
# Processing Record 20 of Set 16 | komsomolets
# Processing Record 21 of Set 16 | bandarbeyla
# Processing Record 22 of Set 16 | edd
# Processing Record 23 of Set 16 | ribeira grande
# Processing Record 24 of Set 16 | turukhansk
# Processing Record 25 of Set 16 | semnan
# Processing Record 26 of Set 16 | douala
# Processing Record 27 of Set 16 | hohhot
# Processing Record 28 of Set 16 | auki
# Processing Record 29 of Set 16 | vigrestad
# Processing Record 30 of Set 16 | umzimvubu
# Processing Record 31 of Set 16 | kahului
# Processing Record 32 of Set 16 | udachnyy
# Processing Record 33 of Set 16 | sentyabrskiy
# Processing Record 34 of Set 16 | narsaq
# Processing Record 35 of Set 16 | vardo
# Processing Record 36 of Set 16 | saint anthony
# Processing Record 37 of Set 16 | santa maria
# Processing Record 38 of Set 16 | novoagansk
# Processing Record 39 of Set 16 | tiksi
# Processing Record 40 of Set 16 | anloga
# Processing Record 41 of Set 16 | saleaula
# Processing Record 42 of Set 16 | paamiut
# Processing Record 43 of Set 16 | batagay-alyta
# Processing Record 44 of Set 16 | katsuura
# Processing Record 45 of Set 16 | lata
# Processing Record 46 of Set 16 | doha
# Processing Record 47 of Set 16 | carnarvon
# Processing Record 48 of Set 16 | hammerfest
# Processing Record 49 of Set 16 | ayagoz
# Processing Record 50 of Set 16 | batavia
# Processing Record 1 of Set 17 | hamilton
# Processing Record 2 of Set 17 | walvis bay
# Processing Record 3 of Set 17 | cherskiy
# Processing Record 4 of Set 17 | kaitangata
# Processing Record 5 of Set 17 | palmer
# Processing Record 6 of Set 17 | kurilsk
# Processing Record 7 of Set 17 | powell
# Processing Record 8 of Set 17 | oranjemund
# Processing Record 9 of Set 17 | youghal
# Processing Record 10 of Set 17 | matagami
# Processing Record 11 of Set 17 | merauke
# Processing Record 12 of Set 17 | fairview
# Processing Record 13 of Set 17 | bima
# Processing Record 14 of Set 17 | hoquiam
# Processing Record 15 of Set 17 | cawayan
# Processing Record 16 of Set 17 | port macquarie
# Processing Record 17 of Set 17 | muros
# Processing Record 18 of Set 17 | george town
# Processing Record 19 of Set 17 | thinadhoo
# Processing Record 20 of Set 17 | ibra
# Processing Record 21 of Set 17 | sulechow
# Processing Record 22 of Set 17 | chicama
# Processing Record 23 of Set 17 | okhotsk
# Processing Record 24 of Set 17 | roma
# Processing Record 25 of Set 17 | aguimes
# Processing Record 26 of Set 17 | guerrero negro
# Processing Record 27 of Set 17 | kungurtug
# Processing Record 28 of Set 17 | kavieng
# Processing Record 29 of Set 17 | comodoro rivadavia
# Processing Record 30 of Set 17 | alvorada
# Processing Record 31 of Set 17 | morondava
# Processing Record 32 of Set 17 | shelburne
# Processing Record 33 of Set 17 | mackay
# Processing Record 34 of Set 17 | contamana
# Processing Record 35 of Set 17 | idrinskoye
# Processing Record 36 of Set 17 | xam nua
# Processing Record 37 of Set 17 | padang
# Processing Record 38 of Set 17 | puerto narino
# Processing Record 39 of Set 17 | lasa
# Processing Record 40 of Set 17 | hasaki
# Processing Record 41 of Set 17 | quibor
# Processing Record 42 of Set 17 | cidreira
# Processing Record 43 of Set 17 | inhambane
# Processing Record 44 of Set 17 | ancud
# Processing Record 45 of Set 17 | bereda
# Processing Record 46 of Set 17 | linjiang
# Processing Record 47 of Set 17 | ponta do sol
# Processing Record 48 of Set 17 | muyezerskiy
# Processing Record 49 of Set 17 | tromso
# Processing Record 50 of Set 17 | nanyang
# Processing Record 1 of Set 18 | longyearbyen
# Processing Record 2 of Set 18 | coro
# Processing Record 3 of Set 18 | uvalde
# Processing Record 4 of Set 18 | yuzhno-yeniseyskiy
# Processing Record 5 of Set 18 | kosh-agach
# Processing Record 6 of Set 18 | la ronge
# Processing Record 7 of Set 18 | mount gambier
# Processing Record 8 of Set 18 | goderich
# Processing Record 9 of Set 18 | palabuhanratu
# Processing Record 10 of Set 18 | savannah bight
# Processing Record 11 of Set 18 | hay river
# Processing Record 12 of Set 18 | campo maior
# Processing Record 13 of Set 18 | lebyazhye
# Processing Record 14 of Set 18 | pontianak
# Processing Record 15 of Set 18 | cizre
# Processing Record 16 of Set 18 | solnechnyy
# Processing Record 17 of Set 18 | jamame
# Processing Record 18 of Set 18 | zonguldak
# Processing Record 19 of Set 18 | naze
# Processing Record 20 of Set 18 | barbar
# Processing Record 21 of Set 18 | genhe
# Processing Record 22 of Set 18 | white rock
# Processing Record 23 of Set 18 | tyukhtet
# Processing Record 24 of Set 18 | beberibe
# Processing Record 25 of Set 18 | sawtell
# Processing Record 26 of Set 18 | indian head
# Processing Record 27 of Set 18 | omsukchan
# Processing Record 28 of Set 18 | half moon bay
# Processing Record 29 of Set 18 | bengkulu
# Processing Record 30 of Set 18 | boa vista
# Processing Record 31 of Set 18 | kamaishi
# Processing Record 32 of Set 18 | vieste
# Processing Record 33 of Set 18 | meulaboh
# Processing Record 34 of Set 18 | san patricio
# Processing Record 35 of Set 18 | mesyagutovo
# Processing Record 36 of Set 18 | stornoway
# Processing Record 37 of Set 18 | ilek
# Processing Record 38 of Set 18 | byron bay
# Processing Record 39 of Set 18 | mapiri
# Processing Record 40 of Set 18 | saint-joseph
# Processing Record 41 of Set 18 | sinjah
# Processing Record 42 of Set 18 | upernavik
# Processing Record 43 of Set 18 | quetigny
# Processing Record 44 of Set 18 | bilma
# Processing Record 45 of Set 18 | sumbe
# Processing Record 46 of Set 18 | keetmanshoop
# Processing Record 47 of Set 18 | binghamton
# Processing Record 48 of Set 18 | kodiak
# Processing Record 49 of Set 18 | gondanglegi
# Processing Record 50 of Set 18 | rosehearty
# Processing Record 1 of Set 19 | kargopol
# Processing Record 2 of Set 19 | homer
# Processing Record 3 of Set 19 | flinders
# Processing Record 4 of Set 19 | dandong
# Processing Record 5 of Set 19 | brae
# Processing Record 6 of Set 19 | dicabisagan
# Processing Record 7 of Set 19 | tuatapere
# Processing Record 8 of Set 19 | lavra
# Processing Record 9 of Set 19 | cururupu
# Processing Record 10 of Set 19 | cabo rojo
# Processing Record 11 of Set 19 | itarema
# Processing Record 12 of Set 19 | sitka
# Processing Record 13 of Set 19 | mackenzie
# Processing Record 14 of Set 19 | skegness
# Processing Record 15 of Set 19 | dalmeny
# Processing Record 16 of Set 19 | nyurba
# Processing Record 17 of Set 19 | saint-augustin
# Processing Record 18 of Set 19 | lewisporte
# Processing Record 19 of Set 19 | boden
# Processing Record 20 of Set 19 | aswan
# Processing Record 21 of Set 19 | vaitape
# Processing Record 22 of Set 19 | asyut
# Processing Record 23 of Set 19 | cabedelo
# Processing Record 24 of Set 19 | makakilo city
# Processing Record 25 of Set 19 | changping
# Processing Record 26 of Set 19 | liyang
# Processing Record 27 of Set 19 | kiruna
# Processing Record 28 of Set 19 | mehamn
# Processing Record 29 of Set 19 | san carlos de bariloche
# Processing Record 30 of Set 19 | chuy
# Processing Record 31 of Set 19 | harper
# Processing Record 32 of Set 19 | port hardy
# Processing Record 33 of Set 19 | lishu
# Processing Record 34 of Set 19 | chapais
# Processing Record 35 of Set 19 | gboko
# Processing Record 36 of Set 19 | karkaralinsk
# Processing Record 37 of Set 19 | port hedland
# Processing Record 38 of Set 19 | jertih
# Processing Record 39 of Set 19 | ternate
# Processing Record 40 of Set 19 | bridgetown
# Processing Record 41 of Set 19 | rafraf
# Processing Record 42 of Set 19 | boo
# Processing Record 43 of Set 19 | lazaro cardenas
# Processing Record 44 of Set 19 | palasa
# Processing Record 45 of Set 19 | shu
# Processing Record 46 of Set 19 | ambon
# Processing Record 47 of Set 19 | alpena
# Processing Record 48 of Set 19 | ugoofaaru
# Processing Record 49 of Set 19 | tomigusuku
# Processing Record 50 of Set 19 | dharchula
# Processing Record 1 of Set 20 | quatre cocos
# Processing Record 2 of Set 20 | cangzhou
# Processing Record 3 of Set 20 | emerald
# Processing Record 4 of Set 20 | nuuk
# Processing Record 5 of Set 20 | jiangkou
# Processing Record 6 of Set 20 | norman wells
# Processing Record 7 of Set 20 | taoudenni
# Processing Record 8 of Set 20 | prince rupert
# Processing Record 9 of Set 20 | myitkyina
# Processing Record 10 of Set 20 | los llanos de aridane
# Processing Record 11 of Set 20 | phan rang
# Processing Record 12 of Set 20 | blagodatnoye
# Processing Record 13 of Set 20 | jujuy
# Processing Record 14 of Set 20 | bonthe
# Processing Record 15 of Set 20 | durango
# Processing Record 16 of Set 20 | tazovskiy
# Processing Record 17 of Set 20 | portland
# Processing Record 18 of Set 20 | tanout
# Processing Record 19 of Set 20 | sumbawa
# Processing Record 20 of Set 20 | yar-sale
# Processing Record 21 of Set 20 | labuhan
# Processing Record 22 of Set 20 | orocue
# Processing Record 23 of Set 20 | tura
# Processing Record 24 of Set 20 | tskaltubo
# Processing Record 25 of Set 20 | nemuro
# Processing Record 26 of Set 20 | lagoa
# Processing Record 27 of Set 20 | taupo
# Processing Record 28 of Set 20 | viedma
# Processing Record 29 of Set 20 | port lincoln
# Processing Record 30 of Set 20 | praia
# Processing Record 31 of Set 20 | cabo san lucas
# Processing Record 32 of Set 20 | nueva guinea
# Processing Record 33 of Set 20 | dongsheng
# Processing Record 34 of Set 20 | port augusta
# Processing Record 35 of Set 20 | puerto madero
# Processing Record 36 of Set 20 | ozgon
# Processing Record 37 of Set 20 | voskresenskoye
# Processing Record 38 of Set 20 | jalu
# Processing Record 39 of Set 20 | marcona
# Processing Record 40 of Set 20 | mareeba
# Processing Record 41 of Set 20 | conceicao do araguaia
# Processing Record 42 of Set 20 | sturgeon falls
# Processing Record 43 of Set 20 | verkh-usugli
# Processing Record 44 of Set 20 | alice springs
# Processing Record 45 of Set 20 | luanda
# Processing Record 46 of Set 20 | yeppoon
# Processing Record 47 of Set 20 | yulara
# Processing Record 48 of Set 20 | tautira
# Processing Record 49 of Set 20 | alunitdag
# Processing Record 50 of Set 20 | moanda
# Processing Record 1 of Set 21 | samarai
# Processing Record 2 of Set 21 | nome
# Processing Record 3 of Set 21 | rotnes
# Processing Record 4 of Set 21 | luena
# Processing Record 5 of Set 21 | dzhusaly
# Processing Record 6 of Set 21 | lac du bonnet
# Processing Record 7 of Set 21 | elko
# Processing Record 8 of Set 21 | nagato
# Processing Record 9 of Set 21 | panalingaan
# Processing Record 10 of Set 21 | beruwala
# Processing Record 11 of Set 21 | miles city
# Processing Record 12 of Set 21 | amahai
# Processing Record 13 of Set 21 | ust-kamchatsk
# Processing Record 14 of Set 21 | padrauna
# Processing Record 15 of Set 21 | ahipara
# Processing Record 16 of Set 21 | desna
# Processing Record 17 of Set 21 | thilogne
# Processing Record 18 of Set 21 | batemans bay
# Processing Record 19 of Set 21 | gat
# Processing Record 20 of Set 21 | vikindu
# Processing Record 21 of Set 21 | touros
# Processing Record 22 of Set 21 | eyl
# Processing Record 23 of Set 21 | bonnyville
# Processing Record 24 of Set 21 | kavaratti
# Processing Record 25 of Set 21 | bambous virieux
# Processing Record 26 of Set 21 | xinyu
# Processing Record 27 of Set 21 | baykit
# Processing Record 28 of Set 21 | aberdeen
# Processing Record 29 of Set 21 | trincomalee
# Processing Record 30 of Set 21 | liverpool
# Processing Record 31 of Set 21 | luderitz
# Processing Record 32 of Set 21 | nantucket
# Processing Record 33 of Set 21 | alta
# Processing Record 34 of Set 21 | ketchikan
# Processing Record 35 of Set 21 | rocha
# Processing Record 36 of Set 21 | ushtobe
# Processing Record 37 of Set 21 | kimbe
# Processing Record 38 of Set 21 | karaul
# Processing Record 39 of Set 21 | saint-paul
# Processing Record 40 of Set 21 | warrington
# Processing Record 41 of Set 21 | swift current
# Processing Record 42 of Set 21 | bitung
# Processing Record 43 of Set 21 | lavrentiya
# Processing Record 44 of Set 21 | poum
# Processing Record 45 of Set 21 | bure
# Processing Record 46 of Set 21 | ewa beach
# Processing Record 47 of Set 21 | codrington
# Processing Record 48 of Set 21 | sibu
# Processing Record 49 of Set 21 | edeia
# Processing Record 50 of Set 21 | jabiru
# Processing Record 1 of Set 22 | chumikan
# Processing Record 2 of Set 22 | neiafu
# Processing Record 3 of Set 22 | shancheng
# Processing Record 4 of Set 22 | kirkwood
# Processing Record 5 of Set 22 | severo-kurilsk
# Processing Record 6 of Set 22 | puerto santander
# Processing Record 7 of Set 22 | najran
# Processing Record 8 of Set 22 | villa del rosario
# Processing Record 9 of Set 22 | giresun
# Processing Record 10 of Set 22 | vastseliina
# Processing Record 11 of Set 22 | vostok
# Processing Record 12 of Set 22 | tumannyy
# Processing Record 13 of Set 22 | limenaria
# Processing Record 14 of Set 22 | banda aceh
# Processing Record 15 of Set 22 | raudeberg
# Processing Record 16 of Set 22 | kuvandyk
# Processing Record 17 of Set 22 | behshahr
# Processing Record 18 of Set 22 | parrita
# Processing Record 19 of Set 22 | toliary
# Processing Record 20 of Set 22 | teya
# Processing Record 21 of Set 22 | sovetskiy
# Processing Record 22 of Set 22 | grand gaube
# Processing Record 23 of Set 22 | nago
# Processing Record 24 of Set 22 | yen bai
# Processing Record 25 of Set 22 | dickinson
# Processing Record 26 of Set 22 | skaudvile
# Processing Record 27 of Set 22 | shuangyang
# Processing Record 28 of Set 22 | bykovo
# Processing Record 29 of Set 22 | ilmajoki
# Processing Record 30 of Set 22 | wuwei
# Processing Record 31 of Set 22 | lyuban
# Processing Record 32 of Set 22 | bouna
# Processing Record 33 of Set 22 | salalah
# Processing Record 34 of Set 22 | lixourion
# Processing Record 35 of Set 22 | namatanai
# Processing Record 36 of Set 22 | arcos de la frontera
# Processing Record 37 of Set 22 | deputatskiy
# Processing Record 38 of Set 22 | sai buri
# Processing Record 39 of Set 22 | artyk
# Processing Record 40 of Set 22 | nouadhibou
# Processing Record 41 of Set 22 | tazmalt
# Processing Record 42 of Set 22 | hualmay
# Processing Record 43 of Set 22 | xai-xai
# Processing Record 44 of Set 22 | chimbarongo
# Processing Record 45 of Set 22 | zihuatanejo
# Processing Record 46 of Set 22 | panjab
# Processing Record 47 of Set 22 | nurota
# Processing Record 48 of Set 22 | puerto escondido
# Processing Record 49 of Set 22 | ca mau
# Processing Record 50 of Set 22 | champerico
# Processing Record 1 of Set 23 | esperance
# Processing Record 2 of Set 23 | kirakira
# Processing Record 3 of Set 23 | verkhnevilyuysk
# Processing Record 4 of Set 23 | sinnamary
# Processing Record 5 of Set 23 | valparaiso
# Processing Record 6 of Set 23 | kloulklubed
# Processing Record 7 of Set 23 | bundaberg
# Processing Record 8 of Set 23 | winsum
# Processing Record 9 of Set 23 | guaratinga
# Processing Record 10 of Set 23 | buala
# Processing Record 11 of Set 23 | prachuap khiri khan
# Processing Record 12 of Set 23 | peterhead
# Processing Record 13 of Set 23 | uyemskiy
# Processing Record 14 of Set 23 | sangar
# Processing Record 15 of Set 23 | uspenka
# Processing Record 16 of Set 23 | farafangana
# Processing Record 17 of Set 23 | hanzhong
# Processing Record 18 of Set 23 | pangoa
# Processing Record 19 of Set 23 | wexford
# Processing Record 20 of Set 23 | vila velha
# Processing Record 21 of Set 23 | westport
# Processing Record 22 of Set 23 | mandalgovi
# Processing Record 23 of Set 23 | mamallapuram
# Processing Record 24 of Set 23 | grants
# Processing Record 25 of Set 23 | emirdag
# Processing Record 26 of Set 23 | saint-georges
# Processing Record 27 of Set 23 | san policarpo
# Processing Record 28 of Set 23 | los algarrobos
# Processing Record 29 of Set 23 | pascagoula
# Processing Record 30 of Set 23 | moose factory
# Processing Record 31 of Set 23 | taltal
# Processing Record 32 of Set 23 | benito soliven
# Processing Record 33 of Set 23 | taybad
# Processing Record 34 of Set 23 | maniitsoq
# Processing Record 35 of Set 23 | broome
# Processing Record 36 of Set 23 | sahuaripa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City    Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Sahuaripa  29.05 -109.2333     75.67        91          85       12.17
#
#   Country                 Date
# 0      MX  2021-08-08 02:46:15

# %%
#Recall that to reorder the columns, we assign a variable to an array of the columns in the order we want them to appear:
#new_column_order = ["column2", "column4", "column1"]
new_column_order = ["City", "Country", 'Date', 'Lat', 'Lng', "Max Temp", 'Humidity','Cloudiness','Wind Speed']

# %%
df = city_data_df[new_column_order]
df
# Out:
#         City Country                 Date    Lat       Lng  Max Temp  \
# 0  Sahuaripa      MX  2021-08-08 02:46:15  29.05 -109.2333     75.67
#
#    Humidity  Cloudiness  Wind Speed
# 0        91          85       12.17

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1628390989.802219

# %%
time.strftime("%x")
# Out:
# '08/07/21'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#         City    Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Sahuaripa  29.05 -109.2333     75.67        91          85       12.17
#
#   Country                 Date
# 0      MX  2021-08-08 02:46:15

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#         City    Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Sahuaripa  29.05 -109.2333     75.67        91          85       12.17
#
#   Country                 Date
# 0      MX  2021-08-08 02:46:15

# %%
city_data_df["Lat"] >= 0
# Out:
# 0    True
# Name: Lat, dtype: bool

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))
# Out:
# /Users/DS/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:160: RuntimeWarning: invalid value encountered in double_scalars
#   slope = ssxym / ssxm
# /Users/DS/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:174: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/DS/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:176: RuntimeWarning: invalid value encountered in double_scalars
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-ce21b4553224> in <module>
#       3 y_values = southern_hemi_df["Max Temp"]
#       4 # Call the function.
# ----> 5 plot_linear_regression(x_values, y_values,
#       6                        'Linear Regression on the Southern Hemisphere \
#       7                         for Maximum Temperature', 'Max Temp',(-50,90))
#
# <ipython-input-62-7b4dd80d07df> in plot_linear_regression(x_values, y_values, title, y_label, text_coordinates)
#       7
#       8     # Run regression on hemisphere weather data.
# ----> 9     (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
#      10
#      11     # Calculate the regression line "y values" from the slope and intercept.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py in linregress(x, y)
#     134
#     135     if x.size == 0 or y.size == 0:
# --> 136         raise ValueError("Inputs must not be empty.")
#     137
#     138     n = len(x)
#
# ValueError: Inputs must not be empty.

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
    'Linear Regression on the Southern Hemisphere for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for Wind Speed', 'Wind Speed',(-50,35))
